# %% [markdown]
# **Introduction**
#
# > This tutorial will showcase some basic DPLA API requests for digital objects on the item level. Before the live coding session, we need to install some Python libraries to help us parse the result. Since we are going to manipulate the retrieved data in JSON format, libraries such as 'flatten_json' and 'pandas' will be useful to have. If the libraries below are already installed on your machine, please feel free to skip.
#
#
# > In general, a metadata record includes objects, array(list), and strings. The type of object retrieved in the metadata record through the API will determine how certain fields of the record to be retrieved through Python code. flatten_json library is useful when a researcher is trying to flatten the DataFrame without worrying much about the type of metadata field.

# %%
pip install flatten_json
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting flatten_json
#   Downloading flatten_json-0.1.13.tar.gz (11 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from flatten_json) (1.15.0)
# Building wheels for collected packages: flatten-json
#   Building wheel for flatten-json (setup.py) ... done
#   Created wheel for flatten-json: filename=flatten_json-0.1.13-py3-none-any.whl size=7978 sha256=2a0a269ff72663a272542b3933bebe661677a9197933ee7f8eda94377b8c7c58
#   Stored in directory: /root/.cache/pip/wheels/87/c5/6d/7a772fecd8d6ebae9e60d997f74b9a96ead7d5a0f26a920090
# Successfully built flatten-json
# Installing collected packages: flatten-json
# Successfully installed flatten-json-0.1.13

# %%
pip install pandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/dist-packages (1.3.5)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas) (2022.6)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.8/dist-packages (from pandas) (1.21.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)

# %%
pip install requests
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (2.23.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests) (2022.12.7)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests) (2.10)

# %% [markdown]
# > Once the libraries were installed, we need to import the modules first for their later use. import Pandas as pd for ease of typing later.

# %%
import requests
import pandas as pd
import flatten_json

# %% [markdown]
# > We use a simple requests function to parse HTTP requests from the API. The API GET results will be store in the variable 'r'.
#
# > What we are doing here is a simple search function of the API, the parameter of 'q' stands for the query terms used for the search.
#
# > In addition, 'apikey' is where you enter the key obtained from DPLA.
#
# > More syntax for the HTTP request can be found in the DPLA API tutorial here: https://pro.dp.la/developers/requests
#
# > In the future, it would be nice to have individual variables defined in the notebook so that users can just plug in values without worrying about the HTTP syntax

# %%
r = requests.get('https://api.dp.la/v2/items?q=cats&api_key=5d03033b8bd8e60c7c34aef1d148d7f3')

# %% [markdown]
# > Make sure the results have been successfully retrieved, meaning getting a 200 response code.
#
# > Other response code explanations can be found here for troubleshoot: https://www.w3.org/Protocols/HTTP/HTRESP.html

# %%
r
# Out:
# <Response [200]>

# %% [markdown]
# > After making sure the results can be successfully downloaded, we can go ahead and map the request results into the json format using json() function. 'output' will be our new variable housing the values 'r' in json format.

# %%
output = r.json()

# %% [markdown]
# > Display keys of the json file in the form of a Python dictionary, which helps to identify which field might be useful for examination.
#
# > But before doing this step for other repositories (with REST APIs), you might want to perform a GET request in your brower address bar to examine what types of structure the json data have. That way, it gives your chances to explore the data structure on a bird's-eye view so it would provide insights of how you want to download the data you need. Since some repositories have limits of how much data you can download during a certain periods of time. So it would be wise to figure out what is the data you need first, so it would be easier for cleaning up the unnecesary data later.
#
# > There are plenty of json plug-ins for commonly used browsers. For example, I used JSON Viewer for my Chrome browser.

# %%
output.keys()
# Out:
# dict_keys(['count', 'docs', 'facets', 'limit', 'start'])

# %% [markdown]
# > First, let's take a look at 'docs' since it is semantically closest to item descriptions/metadata which we are looking for. We then assign the values to the variable 'o'

# %%
o = output['docs']

# %% [markdown]
# > Let's take a look at what we have got by 'printing' o.

# %%
o
# Out:
# [{'@context': 'http://dp.la/api/items/context',
#   '@id': 'http://dp.la/api/items/120144529501c589e3e944ece28f986c',
#   '@type': 'ore:Aggregation',
#   'aggregatedCHO': '#sourceResource',
#   'dataProvider': {'@id': 'http://dp.la/api/contributor/illinois-state-university',
#    'exactMatch': ['http://www.wikidata.org/entity/Q558922'],
#    'name': 'Illinois State University'},
#   'id': '120144529501c589e3e944ece28f986c',
#   'iiifManifest': 'http://digital.library.illinoisstate.edu/iiif/info/icca/8196/manifest.json',
#   'ingestDate': '2022-10-27T19:49:02.165Z',
#   'ingestType': 'item',
#   'isShownAt': 'http://digital.library.illinoisstate.edu/cdm/ref/collection/icca/id/8196',
#   'object': 'http://digital.library.illinoisstate.edu/utils/getthumbnail/collection/icca/id/8196',
#   'originalRecord': {'stringValue': '<record xmlns="http://www.openarchives.org/OAI/2.0/" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance"><header><identifier>urn:dpla-repox.carli.illinois.edu:isu_icca:oai:digital.library.illinoisstate.edu:icca/8196</identifier><datestamp>2022-10-24</datestamp><setSpec>isu_icca</setSpec></header><metadata>\n<oai_qdc:qualifieddc xsi:schemaLocation="http://worldcat.org/xmlschemas/qdc-1.0/ http://worldcat.org/xmlschemas/qdc/1.0/qdc-1.0.xsd http://purl.org/net/oclcterms http://worldcat.org/xmlschemas/oclcterms/1.4/oclcterms-1.4.xsd" xmlns:oai_qdc="http://worldcat.org/xmlschemas/qdc-1.0/" xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:dcterms="http://purl.org/dc/terms/" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance">\n<dc:title>Cats and More Cats</dc:title><dcterms:provenance xmlns:oaiProvenance="http://www.openarchives.org/OAI/2.0/provenance" xmlns:default="http://www.openarchives.org/OAI/2.0/" xmlns:oai_dc="http://www.openarchives.org/OAI/2.0/oai_dc/">Illinois State University</dcterms:provenance>\n<dcterms:spatial>Jacksonville, Illinois, United States</dcterms:spatial>\n<dcterms:created>1960</dcterms:created>\n<dcterms:medium>water-based painting</dcterms:medium>\n<dcterms:extent>48.3 cm x 48.3 cm</dcterms:extent>\n<dc:subject>animals; cats; interior; pets; yarn</dc:subject>\n<dc:type>Image</dc:type>\n<dc:contributor>Franklin Elementary School</dc:contributor>\n<dcterms:isPartOf>International Collection of Child Art (ICCA)</dcterms:isPartOf>\n<dc:rights>In copyright</dc:rights>\n<dc:publisher>Illinois State University. Milner Library</dc:publisher>\n<dc:source>Grant funding for digitization of the ICCA by the Illinois State Library. Funds provided by the Institute of Museum and Library Services under the Federal Library Services &amp; Technology Act.</dc:source>\n<dc:identifier>USA-1178</dc:identifier>\n<dc:type>Image</dc:type>\n<dc:identifier>http://digital.library.illinoisstate.edu/cdm/ref/collection/icca/id/8196</dc:identifier><edm:preview xmlns:edm="http://www.europeana.eu/schemas/edm/">http://digital.library.illinoisstate.edu/utils/getthumbnail/collection/icca/id/8196</edm:preview><edm:iiifManifest xmlns:edm="http://www.europeana.eu/schemas/edm/">http://digital.library.illinoisstate.edu/iiif/info/icca/8196/manifest.json</edm:iiifManifest><edm:isShownAt xmlns:edm="http://www.europeana.eu/schemas/edm/">http://digital.library.illinoisstate.edu/cdm/ref/collection/icca/id/8196</edm:isShownAt></oai_qdc:qualifieddc></metadata><about><oaiProvenance:provenance xsi:schemaLocation="http://www.openarchives.org/OAI/2.0/provenance http://www.openarchives.org/OAI/2.0/provenance.xsd" xmlns:oaiProvenance="http://www.openarchives.org/OAI/2.0/provenance" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance"><oaiProvenance:originDescription harvestDate="2022-10-24" altered="true"><oaiProvenance:baseURL>http://digital.library.illinoisstate.edu/oai/oai.php</oaiProvenance:baseURL><oaiProvenance:identifier>oai:digital.library.illinoisstate.edu:icca/8196</oaiProvenance:identifier><oaiProvenance:datestamp>2022-10-24</oaiProvenance:datestamp><oaiProvenance:metadataNamespace>http://purl.org/dc/terms/</oaiProvenance:metadataNamespace></oaiProvenance:originDescription></oaiProvenance:provenance></about></record>'},
#   'provider': {'@id': 'http://dp.la/api/contributor/il',
#    'exactMatch': ['http://www.wikidata.org/entity/Q83878467'],
#    'name': 'Illinois Digital Heritage Hub'},
#   'rightsCategory': 'Unspecified Rights Status',
#   'sourceResource': {'@id': 'http://dp.la/api/items/120144529501c589e3e944ece28f986c#SourceResource',
#    'collection': [{'title': 'International Collection of Child Art (ICCA)'}],
#    'contributor': ['Franklin Elementary School'],
#    'date': [{'begin': '1960', 'displayDate': '1960', 'end': '1960'}],
#    'format': ['Water-based painting'],
#    'rights': ['In copyright'],
#    'spatial': [{'name': 'Jacksonville, Illinois, United States'}],
#    'subject': [{'name': 'Animals'},
#     {'name': 'Cats'},
#     {'name': 'Interior'},
#     {'name': 'Pets'},
#     {'name': 'Yarn'}],
#    'title': ['Cats and More Cats'],
#    'type': ['image']}},
#  {'@context': 'http://dp.la/api/items/context',
#   '@id': 'http://dp.la/api/items/7fa9791a9dad59e272aa0fb5eacba56b',
#   '@type': 'ore:Aggregation',
#   'aggregatedCHO': '#sourceResource',
#   'dataProvider': {'@id': 'http://dp.la/api/contributor/university-of-kentucky',
#    'exactMatch': ['http://www.wikidata.org/entity/Q1360303'],
#    'name': 'University of Kentucky'},
#   'id': '7fa9791a9dad59e272aa0fb5eacba56b',
#   'ingestDate': '2022-08-09T15:07:52.194Z',
#   'ingestType': 'item',
#   'isShownAt': 'https://exploreuk.uky.edu/catalog/xt734t6f3d29_4066_1',
#   'originalRecord': {'stringValue': '{\n  "_type" : "item",\n  "_id" : "kentucky--http://kdl.kyvl.org/catalog/xt734t6f3d29_4066_1",\n  "_source" : {\n    "dataProvider" : "University of Kentucky",\n    "admin" : {\n      "object_status" : 1\n    },\n    "sourceResource" : {\n      "rights" : "This digital resource may be freely searched and displayed. Permission must be received for subsequent distribution in print or electronically. Physical rights are retained by the owning repository. Copyright is retained in accordance with U. S. copyright laws. Please go to http://kdl.kyvl.org for more information.",\n      "language" : [ {\n        "iso639_3" : "eng",\n        "name" : "English"\n      } ],\n      "title" : [ "Cats", "Two sleepy cats" ],\n      "type" : [ "image" ],\n      "format" : "Images",\n      "creator" : "Weddle, James Edwin, 1911-1989",\n      "@id" : "http://dp.la/api/items/7fa9791a9dad59e272aa0fb5eacba56b#sourceResource"\n    },\n    "object" : "http://nyx.uky.edu/dips/xt734t6f3d29/data/1997av27/1997av27_29/1997av27_29_4083_p/1997av027_4079/1997av027_4079_tb.jpg",\n    "aggregatedCHO" : "#sourceResource",\n    "provider" : {\n      "@id" : "http://dp.la/api/contributor/kdl",\n      "name" : "Kentucky Digital Library"\n    },\n    "ingestDate" : "2019-09-23T17:17:40.785141Z",\n    "id" : "7fa9791a9dad59e272aa0fb5eacba56b",\n    "originalRecord" : {\n      "status" : [ ],\n      "publisher" : "University of Kentucky",\n      "handle" : "http://kdl.kyvl.org/catalog/xt734t6f3d29_4066_1",\n      "language" : "english",\n      "rights" : "This digital resource may be freely searched and displayed. Permission must be received for subsequent distribution in print or electronically. Physical rights are retained by the owning repository. Copyright is retained in accordance with U. S. copyright laws. Please go to http://kdl.kyvl.org for more information.",\n      "type" : "image",\n      "format" : "images",\n      "label" : "Cats; Two sleepy cats",\n      "source" : "James Edwin \\"Ed\\" Weddle Photographic Collection",\n      "relation" : "http://nyx.uky.edu/dips/xt734t6f3d29/data/1997av27/1997av27_29/1997av27_29_4083_p/1997av027_4079/1997av027_4079.jpg",\n      "provider" : {\n        "@id" : "http://dp.la/api/contributor/kdl",\n        "name" : "Kentucky Digital Library"\n      },\n      "datestamp" : "2015-01-08T20:36:23Z",\n      "title" : "Cats; Two sleepy cats",\n      "creator" : "Weddle, James Edwin, 1911-1989.",\n      "id" : "kdl.kyvl.org/xt734t6f3d29_4066_1"\n    },\n    "ingestionSequence" : null,\n    "isShownAt" : "https://exploreuk.uky.edu/catalog/xt734t6f3d29_4066_1",\n    "@context" : "http://dp.la/api/items/context",\n    "ingestType" : "item",\n    "_id" : "kentucky--http://kdl.kyvl.org/catalog/xt734t6f3d29_4066_1",\n    "@id" : "http://dp.la/api/items/7fa9791a9dad59e272aa0fb5eacba56b",\n    "@type" : "ore:Aggregation"\n  }\n}'},
#   'provider': {'@id': 'http://dp.la/api/contributor/kdl',
#    'exactMatch': ['http://www.wikidata.org/entity/Q83878473'],
#    'name': 'Kentucky Digital Library'},
#   'rightsCategory': 'Unspecified Rights Status',
#   'sourceResource': {'@id': 'http://dp.la/api/items/7fa9791a9dad59e272aa0fb5eacba56b#SourceResource',
#    'creator': ['Weddle, James Edwin, 1911-1989'],
#    'format': ['Images'],
#    'language': [{'iso639_3': 'English', 'name': 'English'}],
#    'rights': ['This digital resource may be freely searched and displayed. Permission must be received for subsequent distribution in print or electronically. Physical rights are retained by the owning repository. Copyright is retained in accordance with U. S. copyright laws. Please go to http://kdl.kyvl.org for more information.'],
#    'title': ['Cats', 'Two sleepy cats'],
#    'type': ['image']}},
#  {'@context': 'http://dp.la/api/items/context',
#   '@id': 'http://dp.la/api/items/645bb3361585ed0424b6c3cef35b917b',
#   '@type': 'ore:Aggregation',
#   'aggregatedCHO': '#sourceResource',
#   'dataProvider': {'@id': 'http://dp.la/api/contributor/pepperdine-university-special-collections-and-university-archives',
#    'exactMatch': ['http://www.wikidata.org/entity/'],
#    'name': 'Pepperdine University, Special Collections and University Archives'},
#   'id': '645bb3361585ed0424b6c3cef35b917b',
#   'ingestDate': '2022-08-22T16:25:15.617Z',
#   'ingestType': 'item',
#   'isShownAt': 'http://cdm15730.contentdm.oclc.org/cdm/ref/collection/p15730coll8/id/1499',
#   'object': 'https://thumbnails.calisphere.org/clip/150x150/fb355d89ad9745b926cce8fe791f4f99',
#   'originalRecord': {'stringValue': '{\n  "url_item" : "http://cdm15730.contentdm.oclc.org/cdm/ref/collection/p15730coll8/id/1499",\n  "description" : [ "Photograph likely taken at Coral [Corral] Beach. Item found in the Malibu Times Scrapbook (https://pepperdine.contentdm.oclc.org/digital/collection/p15730coll8/id/1227) with the caption, \\"Susie and the last of the 84th kittens. Born Labor Day 1941.\\"" ],\n  "publisher" : [ "Pepperdine University Libraries", "Malibu Historical Photograph Collection [digital resource], Pepperdine University Special Collections and University Archives" ],\n  "publisher_ss" : [ "Pepperdine University Libraries", "Malibu Historical Photograph Collection [digital resource], Pepperdine University Special Collections and University Archives" ],\n  "facet_decade" : [ "1940s" ],\n  "format" : [ "image/tiff" ],\n  "format_ss" : [ "image/tiff" ],\n  "harvest_id_s" : "26687--oai:cdm15730.contentdm.oclc.org:p15730coll8/1499",\n  "sort_title" : "cats",\n  "repository_url" : [ "https://registry.cdlib.org/api/v1/repository/154/" ],\n  "sort_date_end" : "1941-01-01T00:00:00Z",\n  "sort_date_start" : "1941-01-01T00:00:00Z",\n  "date" : [ "Fall 1941", "1941-10", "1941-11", "1941-12" ],\n  "date_ss" : [ "Fall 1941", "1941-10", "1941-11", "1941-12" ],\n  "rights" : [ "Copyright to photographs in this collection, in most cases, is retained by Pepperdine University. Images are intended for educational and research use, and may be used for non-commercial purposes with appropriate attribution. Organizations and individuals seeking to use images for publication must assume all responsibility for identifying and satisfying any claimants of copyright. Such parties should contact Pepperdine University Special Collections and University Archives." ],\n  "rights_ss" : [ "Copyright to photographs in this collection, in most cases, is retained by Pepperdine University. Images are intended for educational and research use, and may be used for non-commercial purposes with appropriate attribution. Organizations and individuals seeking to use images for publication must assume all responsibility for identifying and satisfying any claimants of copyright. Such parties should contact Pepperdine University Special Collections and University Archives." ],\n  "id" : "bbba572e6a95f8d29abcd06c1444b805",\n  "subject" : [ "Cats", "Malibu (Calif.)", "Corral Beach, Malibu", "Malibu Historical Collection" ],\n  "subject_ss" : [ "Cats", "Malibu (Calif.)", "Corral Beach, Malibu", "Malibu Historical Collection" ],\n  "collection_url" : [ "https://registry.cdlib.org/api/v1/collection/26687/" ],\n  "repository_name" : [ "Pepperdine University, Special Collections and University Archives" ],\n  "reference_image_md5" : "fb355d89ad9745b926cce8fe791f4f99",\n  "repository_data" : [ "https://registry.cdlib.org/api/v1/repository/154/::Pepperdine University, Special Collections and University Archives" ],\n  "title" : [ "Cats" ],\n  "title_ss" : [ "Cats" ],\n  "reference_image_dimensions" : "1022:720",\n  "provenance" : [ "Scrapbook found in the Malibu Times office, then donated by the Malibu Times to Pepperdine Libraries." ],\n  "collection_data" : [ "https://registry.cdlib.org/api/v1/collection/26687/::Malibu Historical Photograph Collection" ],\n  "sort_collection_data" : [ "malibu historical photograph collection:Malibu Historical Photograph Collection:https://registry.cdlib.org/api/v1/collection/26687/" ],\n  "collection_name" : [ "Malibu Historical Photograph Collection" ],\n  "relation" : [ "Malibu Historical Photograph Collection" ],\n  "relation_ss" : [ "Malibu Historical Photograph Collection" ],\n  "identifier" : [ "malibu00371.tif", "http://cdm15730.contentdm.oclc.org/cdm/ref/collection/p15730coll8/id/1499" ],\n  "identifier_ss" : [ "malibu00371.tif", "http://cdm15730.contentdm.oclc.org/cdm/ref/collection/p15730coll8/id/1499" ],\n  "type" : [ "image" ],\n  "type_ss" : [ "image" ],\n  "_version_" : 1734370226914459648,\n  "timestamp" : "2022 ...
#   'provider': {'@id': 'http://dp.la/api/contributor/cdl',
#    'exactMatch': ['http://www.wikidata.org/entity/Q5020447'],
#    'name': 'California Digital Library'},
#   'rightsCategory': 'Unspecified Rights Status',
#   'sourceResource': {'@id': 'http://dp.la/api/items/645bb3361585ed0424b6c3cef35b917b#SourceResource',
#    'collection': [{'title': 'Malibu Historical Photograph Collection'}],
#    'date': [{'displayDate': 'Fall 1941'},
#     {'displayDate': '1941-10'},
#     {'displayDate': '1941-11'},
#     {'displayDate': '1941-12'}],
#    'description': ['Photograph likely taken at Coral [Corral] Beach. Item found in the Malibu Times Scrapbook (https://pepperdine.contentdm.oclc.org/digital/collection/p15730coll8/id/1227) with the caption, "Susie and the last of the 84th kittens. Born Labor Day 1941."'],
#    'identifier': ['malibu00371.tif',
#     'http://cdm15730.contentdm.oclc.org/cdm/ref/collection/p15730coll8/id/1499'],
#    'publisher': ['Pepperdine University Libraries',
#     'Malibu Historical Photograph Collection [digital resource], Pepperdine University Special Collections and University Archives'],
#    'relation': ['Malibu Historical Photograph Collection'],
#    'rights': ['Copyright to photographs in this collection, in most cases, is retained by Pepperdine University. Images are intended for educational and research use, and may be used for non-commercial purposes with appropriate attribution. Organizations and individuals seeking to use images for publication must assume all responsibility for identifying and satisfying any claimants of copyright. Such parties should contact Pepperdine University Special Collections and University Archives.'],
#    'subject': [{'name': 'Cats'},
#     {'name': 'Malibu (Calif.)'},
#     {'name': 'Corral Beach, Malibu'},
#     {'name': 'Malibu Historical Collection'}],
#    'title': ['Cats'],
#    'type': ['image']}},
#  {'@context': 'http://dp.la/api/items/context',
#   '@id': 'http://dp.la/api/items/f5a6af1ad25a74a4e4b821a34045e930',
#   '@type': 'ore:Aggregation',
#   'aggregatedCHO': '#sourceResource',
#   'dataProvider': {'@id': 'http://dp.la/api/contributor/uc-san-diego-special-collections-and-archives',
#    'exactMatch': ['http://www.wikidata.org/entity/'],
#    'name': 'UC San Diego, Special Collections and Archives'},
#   'id': 'f5a6af1ad25a74a4e4b821a34045e930',
#   'ingestDate': '2022-08-22T16:25:15.617Z',
#   'ingestType': 'item',
#   'isShownAt': 'https://library.ucsd.edu/dc/object/bb0888354q',
#   'object': 'https://thumbnails.calisphere.org/clip/150x150/4f9f4a442eb40f5990e9a02404fb4f96',
#   'originalRecord': {'stringValue': '{\n  "url_item" : "https://library.ucsd.edu/dc/object/bb0888354q",\n  "description" : [ "Anne Scheffler\'s Hopongo (New Paradise), Rendova cats", "Special Collections & Archives, UC San Diego, La Jolla, 92093-0175 (https://lib.ucsd.edu/sca)", "This digital image is a surrogate of an item from the Harold Scheffler Papers (MSS 481).", "[Title, Date]. Harold Scheffler Papers. MSS 481. Special Collections & Archives, UC San Diego." ],\n  "creator" : [ "Scheffler, Harold W., 1932-" ],\n  "creator_ss" : [ "Scheffler, Harold W., 1932-" ],\n  "facet_decade" : [ "1960s" ],\n  "spatial" : [ "Pacific Islands", "Solomon Islands", "Oceania", "Rendova (Solomon Islands)", "Melanesia" ],\n  "spatial_ss" : [ "Pacific Islands", "Solomon Islands", "Oceania", "Rendova (Solomon Islands)", "Melanesia" ],\n  "sort_title" : "cats",\n  "campus_name" : [ "UC San Diego" ],\n  "date" : [ "between 1967-1969" ],\n  "date_ss" : [ "between 1967-1969" ],\n  "sort_date_end" : "1969-01-01T00:00:00Z",\n  "campus_data" : [ "https://registry.cdlib.org/api/v1/campus/6/::UC San Diego" ],\n  "coverage" : [ "Pacific Islands", "Solomon Islands", "Oceania", "Rendova (Solomon Islands)", "Melanesia" ],\n  "coverage_ss" : [ "Pacific Islands", "Solomon Islands", "Oceania", "Rendova (Solomon Islands)", "Melanesia" ],\n  "repository_url" : [ "https://registry.cdlib.org/api/v1/repository/22/" ],\n  "rights_holder" : [ "Harold W. Scheffler" ],\n  "rights_holder_ss" : [ "Harold W. Scheffler" ],\n  "id" : "ark:/20775/bb0888354q",\n  "harvest_id_s" : "172--bb0888354q",\n  "collection_url" : [ "https://registry.cdlib.org/api/v1/collection/172/" ],\n  "repository_name" : [ "Special Collections and Archives" ],\n  "reference_image_md5" : "4f9f4a442eb40f5990e9a02404fb4f96",\n  "repository_data" : [ "https://registry.cdlib.org/api/v1/repository/22/::Special Collections and Archives::UC San Diego" ],\n  "rights" : [ "Under copyright", "Constraint(s) on Use: This work is protected by the U.S. Copyright Law (Title 17, U.S.C.). Use of this work beyond that allowed by \\"fair use\\" requires written permission of the copyright holder(s). Responsibility for obtaining permissions and any use and distribution of this work rests exclusively with the user and not the UC San Diego Library. Inquiries can be made to the UC San Diego Library program having custody of the work.", "Use: This work is available from the UC San Diego Library. This digital copy of the work is intended to support research, teaching, and private study." ],\n  "rights_ss" : [ "Under copyright", "Constraint(s) on Use: This work is protected by the U.S. Copyright Law (Title 17, U.S.C.). Use of this work beyond that allowed by \\"fair use\\" requires written permission of the copyright holder(s). Responsibility for obtaining permissions and any use and distribution of this work rests exclusively with the user and not the UC San Diego Library. Inquiries can be made to the UC San Diego Library program having custody of the work.", "Use: This work is available from the UC San Diego Library. This digital copy of the work is intended to support research, teaching, and private study." ],\n  "reference_image_dimensions" : "768:518",\n  "campus_url" : [ "https://registry.cdlib.org/api/v1/campus/6/" ],\n  "collection_data" : [ "https://registry.cdlib.org/api/v1/collection/172/::Harold Scheffler Collection" ],\n  "sort_collection_data" : [ "harold scheffler collection:Harold Scheffler Collection:https://registry.cdlib.org/api/v1/collection/172/" ],\n  "collection_name" : [ "Harold Scheffler Collection" ],\n  "title" : [ "Cats" ],\n  "title_ss" : [ "Cats" ],\n  "subject" : [ "Rendova Islanders (Solomon Islands people)", "Portraits", "Pacific Islands", "Solomon Islands", "Oceania", "Rendova (Solomon Islands)", "Melanesia" ],\n  "subject_ss" : [ "Rendova Islanders (Solomon Islands people)", "Portraits", "Pacific Islands", "Solomon Islands", "Oceania", "Rendova (Solomon Islands)", "Melanesia" ],\n  "type" ...
#   'provider': {'@id': 'http://dp.la/api/contributor/cdl',
#    'exactMatch': ['http://www.wikidata.org/entity/Q5020447'],
#    'name': 'California Digital Library'},
#   'rightsCategory': 'Unspecified Rights Status',
#   'sourceResource': {'@id': 'http://dp.la/api/items/f5a6af1ad25a74a4e4b821a34045e930#SourceResource',
#    'collection': [{'title': 'Harold Scheffler Collection'}],
#    'creator': ['Scheffler, Harold W., 1932'],
#    'date': [{'displayDate': 'between 1967-1969'}],
#    'description': ["Anne Scheffler's Hopongo (New Paradise), Rendova cats",
#     'Special Collections & Archives, UC San Diego, La Jolla, 92093-0175 (https://lib.ucsd.edu/sca)',
#     'This digital image is a surrogate of an item from the Harold Scheffler Papers (MSS 481).',
#     '[Title, Date]. Harold Scheffler Papers. MSS 481. Special Collections & Archives, UC San Diego.'],
#    'rights': ['Under copyright',
#     'Constraint(s) on Use: This work is protected by the U.S. Copyright Law (Title 17, U.S.C.). Use of this work beyond that allowed by "fair use" requires written permission of the copyright holder(s). Responsibility for obtaining permissions and any use and distribution of this work rests exclusively with the user and not the UC San Diego Library. Inquiries can be made to the UC San Diego Library program having custody of the work.',
#     'Use: This work is available from the UC San Diego Library. This digital copy of the work is intended to support research, teaching, and private study.'],
#    'spatial': [{'name': 'Pacific Islands'},
#     {'name': 'Solomon Islands'},
#     {'name': 'Oceania'},
#     {'name': 'Rendova (Solomon Islands)'},
#     {'name': 'Melanesia'}],
#    'subject': [{'name': 'Rendova Islanders (Solomon Islands people)'},
#     {'name': 'Portraits'},
#     {'name': 'Pacific Islands'},
#     {'name': 'Solomon Islands'},
#     {'name': 'Oceania'},
#     {'name': 'Rendova (Solomon Islands)'},
#     {'name': 'Melanesia'}],
#    'title': ['Cats'],
#    'type': ['image']}},
#  {'@context': 'http://dp.la/api/items/context',
#   '@id': 'http://dp.la/api/items/4e20c90cd2ea969c6c037966001b919f',
#   '@type': 'ore:Aggregation',
#   'aggregatedCHO': '#sourceResource',
#   'dataProvider': {'@id': 'http://dp.la/api/contributor/california-state-library',
#    'exactMatch': ['http://www.wikidata.org/entity/Q5021042'],
#    'name': 'California State Library'},
#   'id': '4e20c90cd2ea969c6c037966001b919f',
#   'ingestDate': '2022-08-22T16:25:15.617Z',
#   'ingestType': 'item',
#   'isShownAt': 'https://csl.primo.exlibrisgroup.com/discovery/fulldisplay?docid=alma990014662620205115&context=L&vid=01CSL_INST:CSL',
#   'object': 'https://thumbnails.calisphere.org/clip/150x150/197196ce6603ecf321c50b95e0965be9',
#   'originalRecord': {'stringValue': '{\n  "url_item" : "https://csl.primo.exlibrisgroup.com/discovery/fulldisplay?docid=alma990014662620205115&context=L&vid=01CSL_INST:CSL",\n  "description" : [ "Two cats.", "2009-2168.", "Negative no.: GL5242.", "Lee Adams;", "Henry Nourse was born in Alameda County and grew up in Oakland (12th Ave). Photography was a lifelong hobby and his photographs reflect those areas important to him: greater San Francisco Bay area, the Santa Cruz Mountains, and the north Coast.", "Restricted.", "Online image only, no photographic print available." ],\n  "format" : [ "Photographs.", "Nonprojected graphic" ],\n  "format_ss" : [ "Photographs.", "Nonprojected graphic" ],\n  "facet_decade" : [ "1900s", "1910s" ],\n  "harvest_id_s" : "26559--990014662620205115",\n  "sort_title" : "cats",\n  "repository_url" : [ "https://registry.cdlib.org/api/v1/repository/51/" ],\n  "sort_date_end" : "1919-01-01T00:00:00Z",\n  "sort_date_start" : "1900-01-01T00:00:00Z",\n  "extent" : [ "1 negative : glass ; 1 5/8 x 2 in." ],\n  "extent_ss" : [ "1 negative : glass ; 1 5/8 x 2 in." ],\n  "date" : [ "[between 1900 and 1919]" ],\n  "date_ss" : [ "[between 1900 and 1919]" ],\n  "id" : "bd639cf2ef602e2207a4ec3a2ae38c62",\n  "subject" : [ "Cats--California", "Pets", "Oakland (Calif.)--Photographs", "Glass negatives" ],\n  "subject_ss" : [ "Cats--California", "Pets", "Oakland (Calif.)--Photographs", "Glass negatives" ],\n  "collection_url" : [ "https://registry.cdlib.org/api/v1/collection/26559/" ],\n  "repository_name" : [ "California State Library" ],\n  "reference_image_md5" : "197196ce6603ecf321c50b95e0965be9",\n  "repository_data" : [ "https://registry.cdlib.org/api/v1/repository/51/::California State Library" ],\n  "language" : [ "English" ],\n  "language_ss" : [ "English" ],\n  "rights" : [ "Restricted.", "Negatives not available for public viewing." ],\n  "rights_ss" : [ "Restricted.", "Negatives not available for public viewing." ],\n  "reference_image_dimensions" : "150:123",\n  "creator" : [ "Nourse, Henry King, 1880-1968" ],\n  "creator_ss" : [ "Nourse, Henry King, 1880-1968" ],\n  "collection_data" : [ "https://registry.cdlib.org/api/v1/collection/26559/::California History Section Picture Catalog" ],\n  "spatial" : [ "California", "Oakland (Calif.)" ],\n  "spatial_ss" : [ "California", "Oakland (Calif.)" ],\n  "sort_collection_data" : [ "california history section picture catalog:California History Section Picture Catalog:https://registry.cdlib.org/api/v1/collection/26559/" ],\n  "collection_name" : [ "California History Section Picture Catalog" ],\n  "title" : [ "Cats" ],\n  "title_ss" : [ "Cats" ],\n  "coverage" : [ "California", "Oakland (Calif.)" ],\n  "coverage_ss" : [ "California", "Oakland (Calif.)" ],\n  "identifier" : [ "(C)001466262CSL01-Aleph" ],\n  "identifier_ss" : [ "(C)001466262CSL01-Aleph" ],\n  "type" : [ "image" ],\n  "type_ss" : [ "image" ],\n  "_version_" : 1665899107780132864,\n  "timestamp" : "2020-05-06T00:33:12.814Z"\n}'},
#   'provider': {'@id': 'http://dp.la/api/contributor/cdl',
#    'exactMatch': ['http://www.wikidata.org/entity/Q5020447'],
#    'name': 'California Digital Library'},
#   'rightsCategory': 'Unspecified Rights Status',
#   'sourceResource': {'@id': 'http://dp.la/api/items/4e20c90cd2ea969c6c037966001b919f#SourceResource',
#    'collection': [{'title': 'California History Section Picture Catalog'}],
#    'creator': ['Nourse, Henry King, 1880-1968'],
#    'date': [{'displayDate': '[between 1900 and 1919]'}],
#    'description': ['Two cats.',
#     '2009-2168.',
#     'Negative no.: GL5242.',
#     'Lee Adams;',
#     'Henry Nourse was born in Alameda County and grew up in Oakland (12th Ave). Photography was a lifelong hobby and his photographs reflect those areas important to him: greater San Francisco Bay area, the Santa Cruz Mountains, and the north Coast.',
#     'Restricted.',
#     'Online image only, no photographic print available.'],
#    'extent': ['1 negative : glass ; 1 5/8 x 2 in.'],
#    'format': ['Photographs.', 'Nonprojected graphic'],
#    'identifier': ['(C)001466262CSL01-Aleph'],
#    'language': [{'iso639_3': 'English', 'name': 'English'}],
#    'rights': ['Restricted.', 'Negatives not available for public viewing.'],
#    'spatial': [{'name': 'California'}, {'name': 'Oakland (Calif.)'}],
#    'subject': [{'name': 'Cats--California'},
#     {'name': 'Pets'},
#     {'name': 'Oakland (Calif.)--Photographs'},
#     {'name': 'Glass negatives'}],
#    'title': ['Cats'],
#    'type': ['image']}},
#  {'@context': 'http://dp.la/api/items/context',
#   '@id': 'http://dp.la/api/items/f3e02fb1df937990e7be675aeaad374a',
#   '@type': 'ore:Aggregation',
#   'aggregatedCHO': '#sourceResource',
#   'dataProvider': {'@id': 'http://dp.la/api/contributor/california-state-library',
#    'exactMatch': ['http://www.wikidata.org/entity/Q5021042'],
#    'name': 'California State Library'},
#   'id': 'f3e02fb1df937990e7be675aeaad374a',
#   'ingestDate': '2022-08-22T16:25:15.617Z',
#   'ingestType': 'item',
#   'isShownAt': 'https://csl.primo.exlibrisgroup.com/discovery/fulldisplay?docid=alma990014662610205115&context=L&vid=01CSL_INST:CSL',
#   'object': 'https://thumbnails.calisphere.org/clip/150x150/51a25a7e00d80016addc3d074bfb8fee',
#   'originalRecord': {'stringValue': '{\n  "url_item" : "https://csl.primo.exlibrisgroup.com/discovery/fulldisplay?docid=alma990014662610205115&context=L&vid=01CSL_INST:CSL",\n  "description" : [ "Two cats, two boys in background.", "2009-2612.", "Negative no.: GL5241.", "Henry Nourse was born in Alameda County and grew up in Oakland (12th Ave). Photography was a lifelong hobby and his photographs reflect those areas important to him: greater San Francisco Bay area, the Santa Cruz Mountains, and the north Coast.", "Lee Adams;", "Restricted.", "Online image only, no photographic print available." ],\n  "format" : [ "Photographs.", "Nonprojected graphic" ],\n  "format_ss" : [ "Photographs.", "Nonprojected graphic" ],\n  "facet_decade" : [ "1900s", "1910s" ],\n  "harvest_id_s" : "26559--990014662610205115",\n  "sort_title" : "cats",\n  "repository_url" : [ "https://registry.cdlib.org/api/v1/repository/51/" ],\n  "sort_date_end" : "1919-01-01T00:00:00Z",\n  "sort_date_start" : "1900-01-01T00:00:00Z",\n  "extent" : [ "1 negative : glass ; 1 5/8 x 2 in." ],\n  "extent_ss" : [ "1 negative : glass ; 1 5/8 x 2 in." ],\n  "date" : [ "[between 1900 and 1919]" ],\n  "date_ss" : [ "[between 1900 and 1919]" ],\n  "id" : "a855170f2ff7462da841543f695634b8",\n  "subject" : [ "Cats--California", "Oakland (Calif.)--Photographs", "Glass negatives" ],\n  "subject_ss" : [ "Cats--California", "Oakland (Calif.)--Photographs", "Glass negatives" ],\n  "collection_url" : [ "https://registry.cdlib.org/api/v1/collection/26559/" ],\n  "repository_name" : [ "California State Library" ],\n  "reference_image_md5" : "51a25a7e00d80016addc3d074bfb8fee",\n  "repository_data" : [ "https://registry.cdlib.org/api/v1/repository/51/::California State Library" ],\n  "language" : [ "English" ],\n  "language_ss" : [ "English" ],\n  "rights" : [ "Restricted.", "Negatives not available for public viewing." ],\n  "rights_ss" : [ "Restricted.", "Negatives not available for public viewing." ],\n  "reference_image_dimensions" : "150:109",\n  "creator" : [ "Nourse, Henry King, 1880-1968" ],\n  "creator_ss" : [ "Nourse, Henry King, 1880-1968" ],\n  "collection_data" : [ "https://registry.cdlib.org/api/v1/collection/26559/::California History Section Picture Catalog" ],\n  "spatial" : [ "California", "Oakland (Calif.)" ],\n  "spatial_ss" : [ "California", "Oakland (Calif.)" ],\n  "sort_collection_data" : [ "california history section picture catalog:California History Section Picture Catalog:https://registry.cdlib.org/api/v1/collection/26559/" ],\n  "collection_name" : [ "California History Section Picture Catalog" ],\n  "title" : [ "[Cats]" ],\n  "title_ss" : [ "[Cats]" ],\n  "coverage" : [ "California", "Oakland (Calif.)" ],\n  "coverage_ss" : [ "California", "Oakland (Calif.)" ],\n  "identifier" : [ "(C)001466261CSL01-Aleph" ],\n  "identifier_ss" : [ "(C)001466261CSL01-Aleph" ],\n  "type" : [ "image" ],\n  "type_ss" : [ "image" ],\n  "_version_" : 1665899107775938560,\n  "timestamp" : "2020-05-06T00:33:12.81Z"\n}'},
#   'provider': {'@id': 'http://dp.la/api/contributor/cdl',
#    'exactMatch': ['http://www.wikidata.org/entity/Q5020447'],
#    'name': 'California Digital Library'},
#   'rightsCategory': 'Unspecified Rights Status',
#   'sourceResource': {'@id': 'http://dp.la/api/items/f3e02fb1df937990e7be675aeaad374a#SourceResource',
#    'collection': [{'title': 'California History Section Picture Catalog'}],
#    'creator': ['Nourse, Henry King, 1880-1968'],
#    'date': [{'displayDate': '[between 1900 and 1919]'}],
#    'description': ['Two cats, two boys in background.',
#     '2009-2612.',
#     'Negative no.: GL5241.',
#     'Henry Nourse was born in Alameda County and grew up in Oakland (12th Ave). Photography was a lifelong hobby and his photographs reflect those areas important to him: greater San Francisco Bay area, the Santa Cruz Mountains, and the north Coast.',
#     'Lee Adams;',
#     'Restricted.',
#     'Online image only, no photographic print available.'],
#    'extent': ['1 negative : glass ; 1 5/8 x 2 in.'],
#    'format': ['Photographs.', 'Nonprojected graphic'],
#    'identifier': ['(C)001466261CSL01-Aleph'],
#    'language': [{'iso639_3': 'English', 'name': 'English'}],
#    'rights': ['Restricted.', 'Negatives not available for public viewing.'],
#    'spatial': [{'name': 'California'}, {'name': 'Oakland (Calif.)'}],
#    'subject': [{'name': 'Cats--California'},
#     {'name': 'Oakland (Calif.)--Photographs'},
#     {'name': 'Glass negatives'}],
#    'title': ['[Cats]'],
#    'type': ['image']}},
#  {'@context': 'http://dp.la/api/items/context',
#   '@id': 'http://dp.la/api/items/0de98df74de0eb47333e8364e6f5224f',
#   '@type': 'ore:Aggregation',
#   'aggregatedCHO': '#sourceResource',
#   'dataProvider': {'@id': 'http://dp.la/api/contributor/boston-public-library',
#    'exactMatch': ['http://www.wikidata.org/entity/Q894583'],
#    'name': 'Boston Public Library'},
#   'id': '0de98df74de0eb47333e8364e6f5224f',
#   'iiifManifest': 'https://ark.digitalcommonwealth.org/ark:/50959/5h73tn20w/manifest',
#   'ingestDate': '2022-10-31T17:40:41.046Z',
#   'ingestType': 'item',
#   'isShownAt': 'https://ark.digitalcommonwealth.org/ark:/50959/5h73tn20w',
#   'object': 'https://ark.digitalcommonwealth.org/ark:/50959/5h73tn20w/thumbnail',
#   'originalRecord': {'stringValue': '<record>\n  <header>\n    <identifier>oai:digitalcommonwealth.org:commonwealth:5h73tn20w</identifier>\n    <datestamp>2013-09-17T22:55:14Z</datestamp>\n    <setSpec>commonwealth:2j62s484w</setSpec>\n  </header>\n  <metadata>\n    <mods:mods \n    version="3.7" xsi:schemaLocation="http://www.loc.gov/mods/v3 http://www.loc.gov/standards/mods/v3/mods-3-7.xsd" xmlns:xlink="http://www.w3.org/1999/xlink" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:mods="http://www.loc.gov/mods/v3">\n      <mods:titleInfo displayLabel="primary_display" usage="primary">\n        <mods:title>Cats</mods:title>\n      </mods:titleInfo>\n      <mods:name authority="local" type="personal">\n        <mods:namePart>Jones, Leslie</mods:namePart>\n        <mods:namePart type="date">1886-1967</mods:namePart>\n        <mods:role>\n          <mods:roleTerm \n          authorityURI="http://id.loc.gov/vocabulary/relators" authority="marcrelator" valueURI="http://id.loc.gov/vocabulary/relators/pht" type="text">\n            Photographer\n</mods:roleTerm>\n        </mods:role>\n      </mods:name>\n      <mods:typeOfResource>Still image</mods:typeOfResource>\n      <mods:genre \n      displayLabel="general" authorityURI="http://id.loc.gov/vocabulary/graphicMaterials" authority="gmgpc" valueURI="http://id.loc.gov/vocabulary/graphicMaterials/tgm007721">\n        Photographs\n</mods:genre>\n      <mods:genre \n      displayLabel="specific" authorityURI="http://id.loc.gov/vocabulary/graphicMaterials" authority="gmgpc" valueURI="http://id.loc.gov/vocabulary/graphicMaterials/tgm003973">\n        Film negatives\n</mods:genre>\n      <mods:originInfo>\n        <mods:dateCreated \n        keyDate="yes" qualifier="approximate" encoding="w3cdtf" point="start">\n          1934\n</mods:dateCreated>\n        <mods:dateCreated \n        keyDate="yes" qualifier="approximate" encoding="w3cdtf" point="end">\n          1956\n</mods:dateCreated>\n      </mods:originInfo>\n      <mods:physicalDescription>\n        <mods:digitalOrigin>reformatted digital</mods:digitalOrigin>\n        <mods:extent>1 negative : film, black &amp; white ; 4 x 5 in.</mods:extent>\n        <mods:internetMediaType>image/jpeg</mods:internetMediaType>\n        <mods:internetMediaType>image/tiff</mods:internetMediaType>\n        <mods:internetMediaType>image/jp2</mods:internetMediaType>\n      </mods:physicalDescription>\n      <mods:note>\n        Title from information provided by Leslie Jones or the Boston Public Library on the negative or negative sleeve.\n      </mods:note>\n      <mods:note>Date supplied by cataloger.</mods:note>\n      <mods:subject \n      authorityURI="http://id.loc.gov/vocabulary/graphicMaterials" authority="lctgm" valueURI="http://id.loc.gov/vocabulary/graphicMaterials/tgm001785">\n        <mods:topic>Cats</mods:topic>\n</mods:subject>\n      <mods:relatedItem type="host">\n        <mods:titleInfo>\n          <mods:title>Leslie Jones Collection</mods:title>\n        </mods:titleInfo>\n      </mods:relatedItem>\n      <mods:relatedItem type="series">\n        <mods:titleInfo>\n          <mods:title>Animals: Dogs &amp; Cats</mods:title>\n        </mods:titleInfo>\n      </mods:relatedItem>\n      <mods:identifier type="uri">\n        https://ark.digitalcommonwealth.org/ark:/50959/5h73tn20w\n      </mods:identifier>\n      <mods:identifier type="local-accession">08_06_018938</mods:identifier>\n      <mods:location>\n        <mods:physicalLocation>Boston Public Library</mods:physicalLocation>\n        <mods:holdingSimple>\n          <mods:copyInformation>\n            <mods:subLocation>Arts Department</mods:subLocation>\n          </mods:copyInformation>\n        </mods:holdingSimple>\n      </mods:location>\n      <mods:location>\n        <mods:url access="object in context" usage="primary">\n          https://ark.digitalcommonwealth.org/ark:/50959/5h73tn20w\n        </mods:url>\n        <mods:url access="preview">\n          https://ark.d ...
#   'provider': {'@id': 'http://dp.la/api/contributor/digital-commonwealth',
#    'exactMatch': ['http://www.wikidata.org/entity/Q72380652'],
#    'name': 'Digital Commonwealth'},
#   'rightsCategory': 'Unspecified Rights Status',
#   'sourceResource': {'@id': 'http://dp.la/api/items/0de98df74de0eb47333e8364e6f5224f#SourceResource',
#    'collection': [{'title': 'Leslie Jones Collection'}],
#    'creator': ['Jones, Leslie, 1886-1967'],
#    'date': [{'begin': '1934', 'displayDate': '1934-1956', 'end': '1956'}],
#    'description': ['Title from information provided by Leslie Jones or the Boston Public Library on the negative or negative sleeve.',
#     'Date supplied by cataloger.'],
#    'extent': ['1 negative : film, black & white ; 4 x 5 in.'],
#    'format': ['Photographs', 'Film negatives'],
#    'identifier': ['Local accession: 08_06_018938'],
#    'rights': ['All rights reserved.', 'Copyright (c) Leslie Jones.'],
#    'subject': [{'name': 'Cats'}],
#    'title': ['Cats'],
#    'type': ['image']}},
#  {'@context': 'http://dp.la/api/items/context',
#   '@id': 'http://dp.la/api/items/1662e92d39639fa3708a009bb60d91b1',
#   '@type': 'ore:Aggregation',
#   'aggregatedCHO': '#sourceResource',
#   'dataProvider': {'@id': 'http://dp.la/api/contributor/boston-public-library',
#    'exactMatch': ['http://www.wikidata.org/entity/Q894583'],
#    'name': 'Boston Public Library'},
#   'id': '1662e92d39639fa3708a009bb60d91b1',
#   'iiifManifest': 'https://ark.digitalcommonwealth.org/ark:/50959/5h73tn76r/manifest',
#   'ingestDate': '2022-10-31T17:40:41.046Z',
#   'ingestType': 'item',
#   'isShownAt': 'https://ark.digitalcommonwealth.org/ark:/50959/5h73tn76r',
#   'object': 'https://ark.digitalcommonwealth.org/ark:/50959/5h73tn76r/thumbnail',
#   'originalRecord': {'stringValue': '<record>\n  <header>\n    <identifier>oai:digitalcommonwealth.org:commonwealth:5h73tn76r</identifier>\n    <datestamp>2013-09-17T23:06:01Z</datestamp>\n    <setSpec>commonwealth:2j62s484w</setSpec>\n  </header>\n  <metadata>\n    <mods:mods \n    version="3.7" xsi:schemaLocation="http://www.loc.gov/mods/v3 http://www.loc.gov/standards/mods/v3/mods-3-7.xsd" xmlns:xlink="http://www.w3.org/1999/xlink" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:mods="http://www.loc.gov/mods/v3">\n      <mods:titleInfo displayLabel="primary_display" usage="primary">\n        <mods:title>Cats</mods:title>\n      </mods:titleInfo>\n      <mods:name authority="local" type="personal">\n        <mods:namePart>Jones, Leslie</mods:namePart>\n        <mods:namePart type="date">1886-1967</mods:namePart>\n        <mods:role>\n          <mods:roleTerm \n          authorityURI="http://id.loc.gov/vocabulary/relators" authority="marcrelator" valueURI="http://id.loc.gov/vocabulary/relators/pht" type="text">\n            Photographer\n</mods:roleTerm>\n        </mods:role>\n      </mods:name>\n      <mods:typeOfResource>Still image</mods:typeOfResource>\n      <mods:genre \n      displayLabel="general" authorityURI="http://id.loc.gov/vocabulary/graphicMaterials" authority="gmgpc" valueURI="http://id.loc.gov/vocabulary/graphicMaterials/tgm007721">\n        Photographs\n</mods:genre>\n      <mods:genre \n      displayLabel="specific" authorityURI="http://id.loc.gov/vocabulary/graphicMaterials" authority="gmgpc" valueURI="http://id.loc.gov/vocabulary/graphicMaterials/tgm003973">\n        Film negatives\n</mods:genre>\n      <mods:originInfo>\n        <mods:dateCreated keyDate="yes" encoding="w3cdtf">1939</mods:dateCreated>\n      </mods:originInfo>\n      <mods:physicalDescription>\n        <mods:digitalOrigin>reformatted digital</mods:digitalOrigin>\n        <mods:extent>\n          1 negative : film, black &amp; white ; 3 1/8 x 4 1/4 in.\n        </mods:extent>\n        <mods:internetMediaType>image/jpeg</mods:internetMediaType>\n        <mods:internetMediaType>image/tiff</mods:internetMediaType>\n        <mods:internetMediaType>image/jp2</mods:internetMediaType>\n      </mods:physicalDescription>\n      <mods:note>\n        Title and date from information provided by Leslie Jones or the Boston Public Library on the negative or negative sleeve.\n      </mods:note>\n      <mods:subject \n      authorityURI="http://id.loc.gov/vocabulary/graphicMaterials" authority="lctgm" valueURI="http://id.loc.gov/vocabulary/graphicMaterials/tgm001785">\n        <mods:topic>Cats</mods:topic>\n</mods:subject>\n      <mods:relatedItem type="host">\n        <mods:titleInfo>\n          <mods:title>Leslie Jones Collection</mods:title>\n        </mods:titleInfo>\n      </mods:relatedItem>\n      <mods:relatedItem type="series">\n        <mods:titleInfo>\n          <mods:title>Animals: Dogs &amp; Cats</mods:title>\n        </mods:titleInfo>\n      </mods:relatedItem>\n      <mods:identifier type="uri">\n        https://ark.digitalcommonwealth.org/ark:/50959/5h73tn76r\n      </mods:identifier>\n      <mods:identifier type="local-accession">08_06_018966</mods:identifier>\n      <mods:location>\n        <mods:physicalLocation>Boston Public Library</mods:physicalLocation>\n        <mods:holdingSimple>\n          <mods:copyInformation>\n            <mods:subLocation>Arts Department</mods:subLocation>\n          </mods:copyInformation>\n        </mods:holdingSimple>\n      </mods:location>\n      <mods:location>\n        <mods:url access="object in context" usage="primary">\n          https://ark.digitalcommonwealth.org/ark:/50959/5h73tn76r\n        </mods:url>\n        <mods:url access="preview">\n          https://ark.digitalcommonwealth.org/ark:/50959/5h73tn76r/thumbnail\n        </mods:url>\n        <mods:url note="iiif-manifest">\n          https://ark.digitalcommonwealth.org/ark:/50959/5h73tn76r/manifest\n        </mods:url>\n      </m ...
#   'provider': {'@id': 'http://dp.la/api/contributor/digital-commonwealth',
#    'exactMatch': ['http://www.wikidata.org/entity/Q72380652'],
#    'name': 'Digital Commonwealth'},
#   'rightsCategory': 'Unspecified Rights Status',
#   'sourceResource': {'@id': 'http://dp.la/api/items/1662e92d39639fa3708a009bb60d91b1#SourceResource',
#    'collection': [{'title': 'Leslie Jones Collection'}],
#    'creator': ['Jones, Leslie, 1886-1967'],
#    'date': [{'begin': '1939', 'displayDate': '1939', 'end': '1939'}],
#    'description': ['Title and date from information provided by Leslie Jones or the Boston Public Library on the negative or negative sleeve.'],
#    'extent': ['1 negative : film, black & white ; 3 1/8 x 4 1/4 in.'],
#    'format': ['Photographs', 'Film negatives'],
#    'identifier': ['Local accession: 08_06_018966'],
#    'rights': ['All rights reserved.', 'Copyright (c) Leslie Jones.'],
#    'subject': [{'name': 'Cats'}],
#    'title': ['Cats'],
#    'type': ['image']}},
#  {'@context': 'http://dp.la/api/items/context',
#   '@id': 'http://dp.la/api/items/7b181cd7df27ce0946c382924ec90c8f',
#   '@type': 'ore:Aggregation',
#   'aggregatedCHO': '#sourceResource',
#   'dataProvider': {'@id': 'http://dp.la/api/contributor/boston-public-library',
#    'exactMatch': ['http://www.wikidata.org/entity/Q894583'],
#    'name': 'Boston Public Library'},
#   'id': '7b181cd7df27ce0946c382924ec90c8f',
#   'iiifManifest': 'https://ark.digitalcommonwealth.org/ark:/50959/5h73tn84f/manifest',
#   'ingestDate': '2022-10-31T17:40:41.046Z',
#   'ingestType': 'item',
#   'isShownAt': 'https://ark.digitalcommonwealth.org/ark:/50959/5h73tn84f',
#   'object': 'https://ark.digitalcommonwealth.org/ark:/50959/5h73tn84f/thumbnail',
#   'originalRecord': {'stringValue': '<record>\n  <header>\n    <identifier>oai:digitalcommonwealth.org:commonwealth:5h73tn84f</identifier>\n    <datestamp>2013-09-17T23:07:23Z</datestamp>\n    <setSpec>commonwealth:2j62s484w</setSpec>\n  </header>\n  <metadata>\n    <mods:mods \n    version="3.7" xsi:schemaLocation="http://www.loc.gov/mods/v3 http://www.loc.gov/standards/mods/v3/mods-3-7.xsd" xmlns:xlink="http://www.w3.org/1999/xlink" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:mods="http://www.loc.gov/mods/v3">\n      <mods:titleInfo displayLabel="primary_display" usage="primary">\n        <mods:title>Cats</mods:title>\n      </mods:titleInfo>\n      <mods:name authority="local" type="personal">\n        <mods:namePart>Jones, Leslie</mods:namePart>\n        <mods:namePart type="date">1886-1967</mods:namePart>\n        <mods:role>\n          <mods:roleTerm \n          authorityURI="http://id.loc.gov/vocabulary/relators" authority="marcrelator" valueURI="http://id.loc.gov/vocabulary/relators/pht" type="text">\n            Photographer\n</mods:roleTerm>\n        </mods:role>\n      </mods:name>\n      <mods:typeOfResource>Still image</mods:typeOfResource>\n      <mods:genre \n      displayLabel="general" authorityURI="http://id.loc.gov/vocabulary/graphicMaterials" authority="gmgpc" valueURI="http://id.loc.gov/vocabulary/graphicMaterials/tgm007721">\n        Photographs\n</mods:genre>\n      <mods:genre \n      displayLabel="specific" authorityURI="http://id.loc.gov/vocabulary/graphicMaterials" authority="gmgpc" valueURI="http://id.loc.gov/vocabulary/graphicMaterials/tgm003973">\n        Film negatives\n</mods:genre>\n      <mods:originInfo>\n        <mods:dateCreated \n        keyDate="yes" qualifier="approximate" encoding="w3cdtf" point="start">\n          1934\n</mods:dateCreated>\n        <mods:dateCreated \n        keyDate="yes" qualifier="approximate" encoding="w3cdtf" point="end">\n          1956\n</mods:dateCreated>\n      </mods:originInfo>\n      <mods:physicalDescription>\n        <mods:digitalOrigin>reformatted digital</mods:digitalOrigin>\n        <mods:extent>1 negative : film, black &amp; white ; 4 x 5 in.</mods:extent>\n        <mods:internetMediaType>image/jpeg</mods:internetMediaType>\n        <mods:internetMediaType>image/tiff</mods:internetMediaType>\n        <mods:internetMediaType>image/jp2</mods:internetMediaType>\n      </mods:physicalDescription>\n      <mods:note>\n        Title from information provided by Leslie Jones or the Boston Public Library on the negative or negative sleeve.\n      </mods:note>\n      <mods:note>Date supplied by cataloger.</mods:note>\n      <mods:subject \n      authorityURI="http://id.loc.gov/vocabulary/graphicMaterials" authority="lctgm" valueURI="http://id.loc.gov/vocabulary/graphicMaterials/tgm001785">\n        <mods:topic>Cats</mods:topic>\n</mods:subject>\n      <mods:relatedItem type="host">\n        <mods:titleInfo>\n          <mods:title>Leslie Jones Collection</mods:title>\n        </mods:titleInfo>\n      </mods:relatedItem>\n      <mods:relatedItem type="series">\n        <mods:titleInfo>\n          <mods:title>Animals: Dogs &amp; Cats</mods:title>\n        </mods:titleInfo>\n      </mods:relatedItem>\n      <mods:identifier type="uri">\n        https://ark.digitalcommonwealth.org/ark:/50959/5h73tn84f\n      </mods:identifier>\n      <mods:identifier type="local-accession">08_06_018970</mods:identifier>\n      <mods:location>\n        <mods:physicalLocation>Boston Public Library</mods:physicalLocation>\n        <mods:holdingSimple>\n          <mods:copyInformation>\n            <mods:subLocation>Arts Department</mods:subLocation>\n          </mods:copyInformation>\n        </mods:holdingSimple>\n      </mods:location>\n      <mods:location>\n        <mods:url access="object in context" usage="primary">\n          https://ark.digitalcommonwealth.org/ark:/50959/5h73tn84f\n        </mods:url>\n        <mods:url access="preview">\n          https://ark.d ...
#   'provider': {'@id': 'http://dp.la/api/contributor/digital-commonwealth',
#    'exactMatch': ['http://www.wikidata.org/entity/Q72380652'],
#    'name': 'Digital Commonwealth'},
#   'rightsCategory': 'Unspecified Rights Status',
#   'sourceResource': {'@id': 'http://dp.la/api/items/7b181cd7df27ce0946c382924ec90c8f#SourceResource',
#    'collection': [{'title': 'Leslie Jones Collection'}],
#    'creator': ['Jones, Leslie, 1886-1967'],
#    'date': [{'begin': '1934', 'displayDate': '1934-1956', 'end': '1956'}],
#    'description': ['Title from information provided by Leslie Jones or the Boston Public Library on the negative or negative sleeve.',
#     'Date supplied by cataloger.'],
#    'extent': ['1 negative : film, black & white ; 4 x 5 in.'],
#    'format': ['Photographs', 'Film negatives'],
#    'identifier': ['Local accession: 08_06_018970'],
#    'rights': ['All rights reserved.', 'Copyright (c) Leslie Jones.'],
#    'subject': [{'name': 'Cats'}],
#    'title': ['Cats'],
#    'type': ['image']}},
#  {'@context': 'http://dp.la/api/items/context',
#   '@id': 'http://dp.la/api/items/781d02dc5b7f6f9e1febb696117ea947',
#   '@type': 'ore:Aggregation',
#   'aggregatedCHO': '#sourceResource',
#   'dataProvider': {'@id': 'http://dp.la/api/contributor/historic-new-england',
#    'exactMatch': ['http://www.wikidata.org/entity/Q12730014'],
#    'name': 'Historic New England'},
#   'id': '781d02dc5b7f6f9e1febb696117ea947',
#   'ingestDate': '2022-10-31T17:40:41.046Z',
#   'ingestType': 'item',
#   'isShownAt': 'http://gusn.us/330833',
#   'object': 'http://hne-rs.s3.amazonaws.com/filestore/3/1/9/4/7/5_faf2042714ec270/319475scr_d757c435023c94b.jpg',
#   'originalRecord': {'stringValue': '<record>\n  <header>\n    <identifier>oai:digitalcommonwealth.org:commonwealth-oai:9019tn41z</identifier>\n    <datestamp>2020-12-21T07:33:37Z</datestamp>\n    <setSpec>commonwealth-oai:cc08j534v</setSpec>\n  </header>\n  <metadata>\n    <mods:mods \n    version="3.7" xsi:schemaLocation="http://www.loc.gov/mods/v3 http://www.loc.gov/standards/mods/v3/mods-3-7.xsd" xmlns:xlink="http://www.w3.org/1999/xlink" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:mods="http://www.loc.gov/mods/v3">\n      <mods:titleInfo displayLabel="primary_display" usage="primary">\n        <mods:title>Cats</mods:title>\n      </mods:titleInfo>\n      <mods:typeOfResource>Artifact</mods:typeOfResource>\n      <mods:genre \n      displayLabel="general" authorityURI="http://id.loc.gov/vocabulary/graphicMaterials" authority="lctgm" valueURI="http://id.loc.gov/vocabulary/graphicMaterials/tgm007159">\n        Objects\n</mods:genre>\n      <mods:originInfo>\n        <mods:dateCreated keyDate="yes" encoding="w3cdtf" point="start">\n          1926\n        </mods:dateCreated>\n        <mods:dateCreated keyDate="yes" encoding="w3cdtf" point="end">\n          1941\n        </mods:dateCreated>\n      </mods:originInfo>\n      <mods:physicalDescription>\n        <mods:extent>20 glass plate, acetate, and nitrate negatives</mods:extent>\n      </mods:physicalDescription>\n      <mods:relatedItem type="host">\n        <mods:titleInfo>\n          <mods:title>\n            PC053: Yankee Publishing Photograph Collection, 1890-1950\n          </mods:title>\n        </mods:titleInfo>\n      </mods:relatedItem>\n      <mods:identifier type="uri">http://gusn.us/330833</mods:identifier>\n      <mods:identifier type="local-other">330833</mods:identifier>\n      <mods:identifier type="local-call">PC053.01.01.005</mods:identifier>\n      <mods:location>\n        <mods:physicalLocation>Historic New England</mods:physicalLocation>\n      </mods:location>\n      <mods:location>\n        <mods:url access="object in context" usage="primary">\n          http://gusn.us/330833\n        </mods:url>\n        <mods:url access="preview">\n          http://hne-rs.s3.amazonaws.com/filestore/3/1/9/4/7/5_faf2042714ec270/319475scr_d757c435023c94b.jpg\n        </mods:url>\n      </mods:location>\n      <mods:accessCondition displayLabel="license" type="use and reproduction">\n        Contact host institution for more information.\n      </mods:accessCondition>\n      <mods:accessCondition displayLabel="rights" type="use and reproduction">\n        Rights status not evaluated.\n      </mods:accessCondition>\n      <mods:recordInfo>\n        <mods:recordContentSource>Historic New England</mods:recordContentSource>\n        <mods:recordOrigin>OAI-PMH request</mods:recordOrigin>\n      </mods:recordInfo>\n</mods:mods>\n  </metadata>\n</record>'},
#   'provider': {'@id': 'http://dp.la/api/contributor/digital-commonwealth',
#    'exactMatch': ['http://www.wikidata.org/entity/Q72380652'],
#    'name': 'Digital Commonwealth'},
#   'rightsCategory': 'Unspecified Rights Status',
#   'sourceResource': {'@id': 'http://dp.la/api/items/781d02dc5b7f6f9e1febb696117ea947#SourceResource',
#    'collection': [{'title': 'PC053: Yankee Publishing Photograph Collection, 1890-1950'}],
#    'date': [{'begin': '1926', 'displayDate': '1926-1941', 'end': '1941'}],
#    'extent': ['20 glass plate, acetate, and nitrate negatives'],
#    'format': ['Objects'],
#    'identifier': ['Local other: 330833', 'Local call: PC053.01.01.005'],
#    'rights': ['Contact host institution for more information.',
#     'Rights status not evaluated.'],
#    'title': ['Cats']}}]

# %% [markdown]
# > The metadata record are usuaully in the forms of dictionary, list, and string in Python. So our job is to learn and decide what functions we use to parse the json data. For example, the key() function will not work for lists since the 'keys'/index of a list are numbers. From what I have learned, dictionary is usually used in metadata fields that have subfields, such as 'docs' (aka items in a more generic term). Lists are usually used in metadata fields with more uniformed properties, such as 'subject.' However, a nested structure might be used. Taking 'subject' again as an example, inside the list, each item is a dictionary: [{'name': 'Cats'}, {'name': 'Malibu (Calif.)'}, {'name': 'Corral Beach, Malibu'},{'name': 'Malibu Historical Collection'}]
#
# > That's why trying to run o.key() will show an error message

# %%
o.keys()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-5503dbd84f60> in <module>
# ----> 1 o.keys()
#
# AttributeError: 'list' object has no attribute 'keys'

# %% [markdown]
# > If the object is a list, you can get the length of the list so that it's easier to get the index hence retrieve specific metadata fields

# %%
lenth = len(o)
lenth
# Out:
# 10

# %% [markdown]
# > Randomly picked the sixth item in the list as an example

# %%
subject = o[5]['sourceResource']['subject']
subject
# Out:
# [{'name': 'Cats--California'},
#  {'name': 'Oakland (Calif.)--Photographs'},
#  {'name': 'Glass negatives'}]

# %% [markdown]
# > Now that we know the basics of retrieving metadata and objects from a metadata record, this is another way of have a bird's-eye view of the entire metadata structure by using Pandas DataFrame. The head() function is a preview of the first 5 objects of the DataFrame.

# %%
df = pd.DataFrame(o)
df.head()
# Out:
#                          @context  \
# 0  http://dp.la/api/items/context
# 1  http://dp.la/api/items/context
# 2  http://dp.la/api/items/context
# 3  http://dp.la/api/items/context
# 4  http://dp.la/api/items/context
#
#                                                  @id            @type  \
# 0  http://dp.la/api/items/120144529501c589e3e944e...  ore:Aggregation
# 1  http://dp.la/api/items/7fa9791a9dad59e272aa0fb...  ore:Aggregation
# 2  http://dp.la/api/items/645bb3361585ed0424b6c3c...  ore:Aggregation
# 3  http://dp.la/api/items/f5a6af1ad25a74a4e4b821a...  ore:Aggregation
# 4  http://dp.la/api/items/4e20c90cd2ea969c6c03796...  ore:Aggregation
#
#      aggregatedCHO                                       dataProvider  \
# 0  #sourceResource  {'@id': 'http://dp.la/api/contributor/illinois...
# 1  #sourceResource  {'@id': 'http://dp.la/api/contributor/universi...
# 2  #sourceResource  {'@id': 'http://dp.la/api/contributor/pepperdi...
# 3  #sourceResource  {'@id': 'http://dp.la/api/contributor/uc-san-d...
# 4  #sourceResource  {'@id': 'http://dp.la/api/contributor/californ...
#
#                                  id  \
# 0  120144529501c589e3e944ece28f986c
# 1  7fa9791a9dad59e272aa0fb5eacba56b
# 2  645bb3361585ed0424b6c3cef35b917b
# 3  f5a6af1ad25a74a4e4b821a34045e930
# 4  4e20c90cd2ea969c6c037966001b919f
#
#                                         iiifManifest  \
# 0  http://digital.library.illinoisstate.edu/iiif/...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                  ingestDate ingestType  \
# 0  2022-10-27T19:49:02.165Z       item
# 1  2022-08-09T15:07:52.194Z       item
# 2  2022-08-22T16:25:15.617Z       item
# 3  2022-08-22T16:25:15.617Z       item
# 4  2022-08-22T16:25:15.617Z       item
#
#                                            isShownAt  \
# 0  http://digital.library.illinoisstate.edu/cdm/r...
# 1  https://exploreuk.uky.edu/catalog/xt734t6f3d29...
# 2  http://cdm15730.contentdm.oclc.org/cdm/ref/col...
# 3      https://library.ucsd.edu/dc/object/bb0888354q
# 4  https://csl.primo.exlibrisgroup.com/discovery/...
#
#                                               object  \
# 0  http://digital.library.illinoisstate.edu/utils...
# 1                                                NaN
# 2  https://thumbnails.calisphere.org/clip/150x150...
# 3  https://thumbnails.calisphere.org/clip/150x150...
# 4  https://thumbnails.calisphere.org/clip/150x150...
#
#                                       originalRecord  \
# 0  {'stringValue': '<record xmlns="http://www.ope...
# 1  {'stringValue': '{
#   "_type" : "item",
#   "_id"...
# 2  {'stringValue': '{
#   "url_item" : "http://cdm1...
# 3  {'stringValue': '{
#   "url_item" : "https://lib...
# 4  {'stringValue': '{
#   "url_item" : "https://csl...
#
#                                             provider  \
# 0  {'@id': 'http://dp.la/api/contributor/il', 'ex...
# 1  {'@id': 'http://dp.la/api/contributor/kdl', 'e...
# 2  {'@id': 'http://dp.la/api/contributor/cdl', 'e...
# 3  {'@id': 'http://dp.la/api/contributor/cdl', 'e...
# 4  {'@id': 'http://dp.la/api/contributor/cdl', 'e...
#
#               rightsCategory  \
# 0  Unspecified Rights Status
# 1  Unspecified Rights Status
# 2  Unspecified Rights Status
# 3  Unspecified Rights Status
# 4  Unspecified Rights Status
#
#                                       sourceResource
# 0  {'@id': 'http://dp.la/api/items/120144529501c5...
# 1  {'@id': 'http://dp.la/api/items/7fa9791a9dad59...
# 2  {'@id': 'http://dp.la/api/items/645bb3361585ed...
# 3  {'@id': 'http://dp.la/api/items/f5a6af1ad25a74...
# 4  {'@id': 'http://dp.la/api/items/4e20c90cd2ea96...

# %% [markdown]
# > If you prefer to have all the data printed to an spreadsheet file and then check the spreadsheet file offline, you can do that too by using the function 'to-excel().' But one thing to pay attention to is that MS Excel is a propreiatary software, using an open-source is preferable when the data has an open license.

# %%
df.to_excel('test.xlsx')

# %% [markdown]
# > Similarly, you can print any parts of the metadata headings with this method too

# %%
import csv
with open('OUTPUT.csv', 'w') as f:
    for key in o.keys():
        f.write("%s,%s\n"%(key,o[key]))
