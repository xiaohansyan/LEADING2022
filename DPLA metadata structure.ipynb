# %%
pip install flatten_json
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Created wheel for flatten-json: filename=flatten_json-0.1.13-py3-none-any.whl size=7980 sha256=6b3d994fc33f60d3bb01867a576cc8bfdaa2588dedb577992109f4430fe734d6
#   Stored in directory: /root/.cache/pip/wheels/e6/b3/2a/beb2ceb72d11bf335f9c2f87aae26981f6744f3fc885cde665
# Successfully built flatten-json
# ...

# %%
pip install pandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
pip install requests
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import requests
import pandas as pd
import flatten_json

# %%
r = requests.get('https://www.loc.gov/videos/?q=herman+baca&fo=json')

# %%
r
# Out:
# <Response [200]>

# %%
output = r.json()

# %%
output.keys()
# Out:
# dict_keys(['breadcrumbs', 'content', 'content_is_post', 'context', 'description', 'expert_resources', 'facet_trail', 'facet_views', 'facets', 'featured_items', 'form_facets', 'image_url', 'next', 'next_sibling', 'options', 'pages', 'pagination', 'portal', 'previous', 'previous_sibling', 'results', 'search', 'site_type', 'timestamp', 'title', 'type', 'views'])

# %%
o = output['facet_views']#['sourceResource']
o
o#.keys()
#lenth = len(o)
#lenth
#df = pd.DataFrame(output['docs'][0])
#df.to_excel('test.xlsx')
#df.head()


#import csv
#with open('OUTPUT.csv', 'w') as f:
#    for key in o.keys():
#        f.write("%s,%s\n"%(key,o[key]))
# Out:
# {'calendar': 'https://www.loc.gov/film-and-videos/?fo=json&fs=calendar&q=herman+baca',
#  'chart': 'https://www.loc.gov/film-and-videos/?fo=json&fs=chart&q=herman+baca',
#  'current': 'list',
#  'list': 'https://www.loc.gov/film-and-videos/?fo=json&q=herman+baca'}
