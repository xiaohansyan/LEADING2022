# %% [markdown]
# install solrpy client

# %%
pip install solrpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Created wheel for solrpy: filename=solrpy-1.0.0-py3-none-any.whl size=15363 sha256=3809652c03612870eb35bc6ca776214934c86c733832a3aa6def3012a37e1abd
#   Stored in directory: /root/.cache/pip/wheels/5f/41/f8/0591f000d92ef826a3012093e9bfd22163084492a83bca0ac8
# Successfully built solrpy
# ...

# %% [markdown]
# import solr module

# %%
import solr

# %% [markdown]
# connecting to the server

# %%
s = solr.SolrConnection('http://solr.calisphere.org:8083/solr', http_pass = '20069cb3-3f7f-4d03-bf53-6b74b009fb0f' )

# %%
respond = s.query('title:baca')

#respond

#for hit in respond.results:
#    print(hit['title'])
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/solr/core.py in _post(self, url, body, headers)
#     649             try:
# --> 650                 self.conn.request('POST', url, body.encode('UTF-8'), _headers)
#     651                 return check_response_status(self.conn.getresponse())
#
# /usr/lib/python3.7/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1280         """Send a complete request to the server."""
# -> 1281         self._send_request(method, url, body, headers, encode_chunked)
#    1282
#
# /usr/lib/python3.7/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1326             body = _encode(body, 'body')
# -> 1327         self.endheaders(body, encode_chunked=encode_chunked)
#    1328
#
# ...
