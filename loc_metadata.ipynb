# %% [markdown]
# **Introduction**
# > Similarly with the DPLA API tutorial, this session will showcase some basic LOC API requests for digital objects on the item level. Before the live coding session, we need to install some Python libraries to help us parse the result. Since we are going to manipulate the retrieved data in JSON format, libraries such as 'flatten_json' and 'pandas' will be useful to have. If the libraries below are already installed on your machine, please feel free to skip.

# %%
pip install flatten_json
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting flatten_json
#   Downloading flatten_json-0.1.13.tar.gz (11 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from flatten_json) (1.15.0)
# Building wheels for collected packages: flatten-json
#   Building wheel for flatten-json (setup.py) ... done
#   Created wheel for flatten-json: filename=flatten_json-0.1.13-py3-none-any.whl size=7978 sha256=29707293ed2c79892b70d9ebe5ea64eaafcb68f8328c745b4f2a4a0382b5c2be
#   Stored in directory: /root/.cache/pip/wheels/87/c5/6d/7a772fecd8d6ebae9e60d997f74b9a96ead7d5a0f26a920090
# Successfully built flatten-json
# Installing collected packages: flatten-json
# Successfully installed flatten-json-0.1.13

# %%
pip install pandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/dist-packages (1.3.5)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas) (2022.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.8/dist-packages (from pandas) (1.21.6)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)

# %%
pip install requests
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (2.23.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests) (2022.12.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests) (2.10)

# %% [markdown]
# > Once the libraries were installed, we need to import the modules first for their later use.

# %%
import requests
import pandas as pd
import flatten_json

# %% [markdown]
# > We use a simple requests function to parse HTTP requests from the API. The API GET results will be store in the variable 'r'.
#
# > What we are doing here is a simple search function of the API, the parameter of 'q' stands for the query terms used for the search. For LOC, YAML format is also available for downloading your data, so at the end of the request, you should specify the format by adding 'fo=json.' (or fo=yaml if you prefer)
#
# > More syntax for the HTTP request can be found in the LOC API tutorial here: https://www.loc.gov/apis/json-and-yaml/requests/
#
# > Similar to the DPLA tutorial, it would be nice to have individual variables defined in the notebook in the future, so that users can just plug in values without worrying about the HTTP syntax
#
# > Luckily, API keys are not needed for LOC API use, which is very handy

# %%
r = requests.get('https://www.loc.gov/search/?q=chinese+americans&fo=json')

# %% [markdown]
# > Should get a 200 code

# %%
r
# Out:
# <Response [200]>

# %% [markdown]
# > Parse the data in json format

# %%
output = r.json()

# %% [markdown]
# > Displaying the headings for a search result using key() function

# %%
output.keys()
# Out:
# dict_keys(['breadcrumbs', 'expert_resources', 'facet_trail', 'facet_views', 'facets', 'form_facets', 'options', 'pagination', 'results', 'search', 'timestamp', 'views'])

# %% [markdown]
# > 'Results' seems the most likely to have the metadata record we want.

# %%
o = output['results']
o
# Out:
# [{'access_restricted': False,
#   'aka': ['http://www.loc.gov/item/ihas.200197427/',
#    'http://lcweb2.loc.gov/diglib/ihas/loc.natlib.ihas.200197427/',
#    'http://lcweb2.loc.gov/diglib/ihas/loc.natlib.ihas.200197427/default.html',
#    'http://www.loc.gov/item/ihas.200197427',
#    'http://www.loc.gov/resource/ihas.200197427'],
#   'campaigns': [],
#   'description': ['<a href="http://www.loc.gov/pictures/resource/cph.3b01797/"><img src="http://lcweb2.loc.gov/natlib/ihas/warehouse/articles/200197427/0001.jpg" alt="Detail from Chinese Band" width="200" height="250" border="0"  /></a><br />'],
#   'digitized': True,
#   'extract_timestamp': '2022-12-27T09:59:46.399Z',
#   'group': ['special/artbios', 'music-division-articles'],
#   'hassegments': False,
#   'id': 'http://www.loc.gov/item/ihas.200197427/',
#   'image_url': ['https://memory.loc.gov/natlib/ihas/warehouse/articles/200197427/0001.jpg'],
#   'index': 1,
#   'item': {'article': '\r\r\n\r\r\n<div id="bio-content"><div id="bio-image">\r\r\n<p><a href="https://www.loc.gov/pictures/resource/cph.3b01797/"><img src="https://lcweb2.loc.gov/natlib/ihas/warehouse/articles/200197427/0001.jpg" alt="Detail from Chinese Band" width="200" height="250" border="0"  /></a><br /></p>\r\r\nDetail from <a href="https://www.loc.gov/pictures/resource/cph.3b01797/">Chinese Band</a>, c1904. Prints and Photographs Division. \r\r\n</div>\r\r\n</div>\r\r\n<p>The Chinese American  community is the largest ethnic group of Asian Americans in the United States.  At the time of the 2010 census, the population stood at around 3.8 million. The  largest Chinese American communities live in California  and New York. </p>\r\r\n\r\r\n<p>The Chinese were among  the earliest of the Asian peoples to arrive in America;  the first record of Chinese migrants in the United States dates back to 1785. However,  the first major wave of Chinese immigration occurred in the mid-nineteenth  century, following the discovery of gold in California in 1849. During the mid-1800s,  Chinese immigrants were encouraged to come to the United States to work in service  professions that supported the boom towns of the Gold Rush, and to help build  railroads in the West.</p>\r\r\n<p>Between the mid  nineteenth and mid twentieth centuries, most of the Chinese immigrants were  young men from rural backgrounds who only spoke local dialects. The majority  came from the southern Guangdong  region. They brought with them their indigenous musical styles. These included  Cantonese opera and Taishan <em>muyu</em> song, a sub-genre of an important South Chinese narrative song type from the  Taishan region where many of the first immigrants originated, which often  included lyrics about the early Chinese migrant experience. These forms went on  to dominate the Chinese American music scene for more than a century. </p>\r\r\n<p>The Library of Congress  collection includes a recording of a traditional Chinese song, entitled "<a href="https://www.loc.gov/item/ihas.200196394/">Drum Song of  Fengyang</a>."   In this song, which was recorded in San Francisco, California,  by Rulan Chao Pian and Margaret Speaks in August, 1943, a wife complains that her husband is lazy, while the husband  complains that his wife has big feet. The song is well known in China  and many versions exist of comical complaints about family life. But it seems  that this is comedy in the face of adversity, as the song is thought to have originated  in Guandong province as a song sung by refugees of  floods in the north of China who found themselves singing on the street  of cities in Guangdong  province to get money to survive. This  explains why the song is sung in Mandarin, while the language of Guandong is  Cantonese. </p>\r\r\n<p>In 1852, a year after San Francisco experienced  its first full-length Italian opera performance (of Bellini\'s <em>La Sonnambula</em>) Hong Took Tong Chinese  Dramatic Company from Guangdong Province, a 130-member Cantonese opera troupe,  staged the first Chinese opera in the United States. The following year the  same troupe performed in New York City.</p>\r\r\n<p>Chinese opera, like lion dances, quickly became  emblematic of Chinese American life and a powerful source of community. Not  only did visiting troupes from China  make regular visits to the United    States, but theaters devoted to the art form  also sprang up around the country. In the late 1870s and 1880s; the so-called  "golden era" of Chinese theater in America  -- San Francisco  boasted no less than four Cantonese opera venues. </p>\r\r\n<p>During the mid-to-late  nineteenth century, Chinese Americans became the victims of racism. The  anti-Chinese sentiment resulted in the passing by Congress in 1882 of The  Chinese Exclusion Act. Signed into law by President Chester A. Arthur, the Act  created a ten-year moratorium on most Chinese immigration. Although the law as  written allowed for men ...
#    'other_formats': ['https://lcweb2.loc.gov/diglib/ihas/loc.natlib.ihas.200197427/mets.xml'],
#    'profile': 'article',
#    'subject_headings': ['Immigration and Migration',
#     'Songs and Music',
#     'Traditional and Ethnic Songs and Music',
#     'Articles']},
#   'original_format': ['web page'],
#   'other_title': [],
#   'partof': ['the library of congress celebrates the songs of america',
#    'performing arts encyclopedia'],
#   'resources': [],
#   'shelf_id': 'http://www.loc.gov/item/ihas.200197427',
#   'site': ['performingarts'],
#   'subject': ['immigration and migration',
#    'articles',
#    'traditional and ethnic songs and music',
#    'songs and music'],
#   'timestamp': '2022-12-27T10:01:45.036Z',
#   'title': 'Chinese American Song',
#   'type': 'web page',
#   'url': 'https://www.loc.gov/item/ihas.200197427/'},
#  {'access_restricted': False,
#   'aka': ['http://www.loc.gov/item/lcwaN0011557/',
#    'https://tile.loc.gov/storage-services/service/webcapture/project_1/mods/general-web-archives/lcwaN0011557.xml'],
#   'campaigns': [],
#   'contributor': ['organization of chinese americans'],
#   'date': '2002-08-05',
#   'dates': ['2002-01-01T00:00:00Z',
#    '2003-01-01T00:00:00Z',
#    '2004-01-01T00:00:00Z',
#    '2005-01-01T00:00:00Z',
#    '2006-01-01T00:00:00Z',
#    '2007-01-01T00:00:00Z',
#    '2008-01-01T00:00:00Z',
#    '2009-01-01T00:00:00Z',
#    '2010-01-01T00:00:00Z',
#    '2011-01-01T00:00:00Z'],
#   'description': ['Website.   electronic |   Electronic (Form).'],
#   'digitized': True,
#   'extract_timestamp': '2022-12-24T15:10:47.285Z',
#   'group': ['general-web-archives'],
#   'hassegments': False,
#   'id': 'http://www.loc.gov/item/lcwaN0011557/',
#   'image_url': ['https://tile.loc.gov/storage-services/service/webcapture/project_1/thumbnails/lcwaS0016743.jpg'],
#   'index': 2,
#   'item': {'access_condition': ' None',
#    'article_type': 'website',
#    'contributor_names': ['Organization of Chinese Americans'],
#    'created_published': ['United States.'],
#    'form': ['electronic'],
#    'genre': ['website'],
#    'image_url': ['https://tile.loc.gov/storage-services/service/webcapture/project_1/thumbnails/lcwaS0016743.jpg'],
#    'other_formats': ['https://tile.loc.gov/storage-services/service/webcapture/project_1/mods/general-web-archives/lcwaN0011557.xml',
#     'https://tile.loc.gov/storage-services/service/webcapture/project_1/mods/supplementary/lcwaN0011557_wa_supp.xml'],
#    'place': ['united states'],
#    'repository': ' Library of Congress, Washington, D.C., 20540 USA',
#    'scopes': ['None (domain)'],
#    'source_url': ['http://www.ocanatl.org/'],
#    'subject_headings': ['Organization of Chinese Americans',
#     'Asian Americans',
#     'Pacific Islander Americans',
#     'Chinese Americans']},
#   'language': ['english'],
#   'location': ['united states'],
#   'mime_type': ['text/html'],
#   'online_format': ['web page'],
#   'original_format': ['web archive'],
#   'other_title': [],
#   'partof': ['general collections'],
#   'resources': [{'capture_range': 2,
#     'files': 1,
#     'image': 'https://tile.loc.gov/storage-services/service/webcapture/project_1/thumbnails/lcwaS0016743.jpg',
#     'url': 'https://webarchive.loc.gov/all/*/http://www.ocanatl.org/'}],
#   'shelf_id': 'https://tile.loc.gov/storage-services/service/webcapture/project_1/mods/general-web-archives/lcwaN0011557.xml',
#   'site': ['web archives'],
#   'subject': ['website',
#    'chinese americans',
#    'asian americans',
#    'pacific islander americans',
#    'organization of chinese americans'],
#   'timestamp': '2022-12-24T16:35:31.054Z',
#   'title': 'Organization of Chinese Americans (OCA)',
#   'type': 'web archive',
#   'url': 'https://www.loc.gov/item/lcwaN0011557/'},
#  {'access_restricted': False,
#   'aka': ['http://www.loc.gov/item/powmia/pwmaster_105323/',
#    'http://www.loc.gov/resource/powmia/pwmaster_105323/'],
#   'campaigns': [],
#   'contributor': ['joint casualty resolution center'],
#   'contributor_originator': ['joint casualty resolution center'],
#   'date': '1980-08-08',
#   'dates': ['1980-08-08T00:00:00Z'],
#   'description': ['post-1975 Vietnam / IIRN I80-019'],
#   'digitized': True,
#   'extract_timestamp': '2022-12-16T14:19:18.334Z',
#   'group': ['powmia'],
#   'hassegments': False,
#   'id': 'http://www.loc.gov/item/powmia/pwmaster_105323/',
#   'image_url': ['https://tile.loc.gov/storage-services/service/frd/pwmia/48/105323.gif'],
#   'index': 3,
#   'item': {'category': 'Source Report',
#    'country': ['post-1975 Vietnam'],
#    'date_of_report': ['1980-08-08'],
#    'date_time_group': [None],
#    'document_id': 'PWMASTER_105323',
#    'keywords': ['LS', 'Saigon'],
#    'originator': 'JOINT CASUALTY RESOLUTION CENTER, ???',
#    'pages': '13',
#    'reel': ['48'],
#    'source_number': [''],
#    'type': ['refugee report']},
#   'location': ['post-1975 vietnam'],
#   'mime_type': ['application/pdf'],
#   'number': ['none', 'i80-019', 'http://www.loc.gov/item/powmia/pw110370'],
#   'number_former_id': ['http://www.loc.gov/item/powmia/pw110370'],
#   'number_iirn': ['i80-019'],
#   'number_refno': ['none'],
#   'online_format': ['pdf'],
#   'original_format': ['manuscript/mixed material'],
#   'other_title': [],
#   'partof': ['defense pow/mia accounting agency',
#    'source report',
#    '48',
#    'federal research division',
#    'vietnam-era prisoner-of-war/missing-in-action database'],
#   'partof_category': ['source report'],
#   'partof_reel': ['48'],
#   'resources': [{'pdf': 'https://tile.loc.gov/storage-services/service//frd/pwmia/48/105323.pdf',
#     'url': 'https://www.loc.gov/item/powmia/pwmaster_105323/'}],
#   'shelf_id': 'http://www.loc.gov/item/powmia/pwmaster_105323/',
#   'subject': ['saigon', 'ls'],
#   'timestamp': '2022-12-16T14:24:43.877Z',
#   'title': 'CHINESE AMERICAN STILL IN SAIGON',
#   'type': 'manuscript/mixed material',
#   'url': 'https://www.loc.gov/item/powmia/pwmaster_105323/'},
#  {'access_restricted': False,
#   'aka': ['http://www.loc.gov/pictures/collection/det/item/2016817917/',
#    'http://www.loc.gov/item/2016817917/',
#    'http://www.loc.gov/pictures/item/2016817917/',
#    'http://hdl.loc.gov/loc.pnp/det.4a27407',
#    'http://www.loc.gov/resource/det.4a27407/',
#    'http://lccn.loc.gov/2016817917'],
#   'campaigns': [],
#   'contributor': ['detroit publishing co.'],
#   'date': '1890',
#   'dates': ['1890-01-01T00:00:00Z'],
#   'description': ['1 negative : glass ; 5 x 7 in.'],
#   'digitized': True,
#   'extract_timestamp': '2021-09-01T22:35:45.605Z',
#   'group': ['det', 'catalog', 'detroit-publishing-company', 'main-catalog'],
#   'hassegments': False,
#   'id': 'http://www.loc.gov/item/2016817917/',
#   'image_url': ['https://tile.loc.gov/storage-services/service/pnp/det/4a20000/4a27000/4a27400/4a27407_150px.jpg#h=113&w=150',
#    'https://tile.loc.gov/storage-services/service/pnp/det/4a20000/4a27000/4a27400/4a27407t.gif#h=107&w=150',
#    'https://tile.loc.gov/storage-services/service/pnp/det/4a20000/4a27000/4a27400/4a27407r.jpg#h=481&w=640',
#    'https://tile.loc.gov/storage-services/service/pnp/det/4a20000/4a27000/4a27400/4a27407v.jpg#h=769&w=1024'],
#   'index': 4,
#   'item': {'call_number': 'LC-D418-30816 [P&P]',
#    'contributor_names': ['Detroit Publishing Co., publisher '],
#    'contributors': ['Detroit Publishing Co., publisher.'],
#    'control_number': '2016817917',
#    'created': '2017-11-21T05:32:01Z',
#    'created_published': '[between 1890 and 1910]',
#    'created_published_date': '[between 1890 and 1910]',
#    'creators': [{'link': '//www.loc.gov/pictures/related/?fi=name&q=Detroit%20Publishing%20Co.&co=det',
#      'role': 'publisher',
#      'title': 'Detroit Publishing Co.'}],
#    'date': '[between 1890 and 1910]',
#    'digital_id': ['det 4a27407 //hdl.loc.gov/loc.pnp/det.4a27407'],
#    'display_offsite': True,
#    'format': ['still image'],
#    'formats': [{'link': '//www.loc.gov/pictures/related/?fi=format&q=Dry%20plate%20negatives.&co=det',
#      'title': 'Dry plate negatives.'}],
#    'genre': ['Dry plate negatives'],
#    'id': '2016817917',
#    'language': ['eng'],
#    'link': '//www.loc.gov/pictures/item/2016817917/',
#    'marc': '//www.loc.gov/pictures/item/2016817917/marc/',
#    'medium': ['1 negative : glass ; 5 x 7 in.'],
#    'medium_brief': '1 negative :',
#    'mediums': ['1 negative : glass ; 5 x 7 in.'],
#    'modified': '2017-11-21T05:32:01Z',
#    'notes': ['Title devised by cataloger.',
#     'Detroit Publishing Co. no. 30816.',
#     'Gift; State Historical Society of Colorado; 1949.'],
#    'other_control_numbers': ['20125896', 'det1994023878/PP'],
#    'part_of': 'Detroit Publishing Company photograph collection (Library of Congress)',
#    'repository': 'Library of Congress Prints and Photographs Division Washington, D.C. 20540 USA http://hdl.loc.gov/loc.pnp/pp.print',
#    'reproduction_number': 'LC-DIG-det-4a27407 (digital file from original)',
#    'resource_links': ['//hdl.loc.gov/loc.pnp/det.4a27407'],
#    'rights_advisory': 'No known restrictions on publication.',
#    'rights_information': 'No known restrictions on publication.',
#    'service_low': 'https://tile.loc.gov/storage-services/service/pnp/det/4a20000/4a27000/4a27400/4a27407_150px.jpg',
#    'service_medium': 'https://tile.loc.gov/storage-services/service/pnp/det/4a20000/4a27000/4a27400/4a27407r.jpg',
#    'sort_date': '1890',
#    'source_collection': ['Detroit Publishing Company photograph collection (Library of Congress)'],
#    'source_created': '1994-01-01T00:00:00Z',
#    'source_modified': '2017-11-03T12:11:49Z',
#    'subject_headings': ['Chinese Americans.', 'Interiors.', 'Narcotics.'],
#    'subjects': ['Chinese Americans', 'Interiors', 'Narcotics'],
#    'thumb_gallery': 'https://tile.loc.gov/storage-services/service/pnp/det/4a20000/4a27000/4a27400/4a27407_150px.jpg',
#    'title': '[Chinese Americans in an opium den]'},
#   'language': ['english'],
#   'mime_type': ['image/gif', 'image/jpg', 'image/tif'],
#   'number': ['http://www.loc.gov/item/det1994023878/pp',
#    'http://www.loc.gov/item/20125896'],
#   'number_former_id': ['http://www.loc.gov/item/20125896',
#    'http://www.loc.gov/item/det1994023878/pp'],
#   'online_format': ['image'],
#   'original_format': ['photo, print, drawing'],
#   'other_title': [],
#   'partof': ['american memory',
#    'catalog',
#    'detroit publishing company',
#    'prints and photographs division'],
#   'related': {'neighbors': '//www.loc.gov/pictures/related/?&co=det&pk=2016817917&st=gallery&sb=call_number#focus'},
#   'reproductions': '<p>If an image is displaying, you can download it yourself. (Some images \ndisplay only as thumbnails outside the Library of Congress because of rights \nconsiderations, but you have access to larger size images on site.)\n</p>\n\n<p>  \nAlternatively, you can purchase copies of various types through Library \nof Congress Duplication Services</a>.\n</p>\n\n<p> \n<ol>\n<p>\n<li><strong>If a digital image is displaying:</strong> The qualities of the digital image \npartially depend on whether it was made from the original or an \nintermediate such as a copy negative or transparency. If the Reproduction \nNumber field above includes a reproduction number that starts with \nLC-DIG..., then there is a digital image that was made directly \nfrom the original and is of sufficient resolution for most publication\n purposes.\n</li> \n</p>\n\n<li><strong>If there is information listed in the Reproduction Number field above:</strong> \nYou can use the reproduction number to purchase a copy from Duplication \nServices.  It will be made from the source listed in the parentheses after\n the number.  \n<p> \nIf only black-and-white (&quot;b&w&quot;) sources are listed and you \n desire a copy showing color or tint (assuming the original has any), \n you can generally purchase a quality copy of the original in color by \n citing the Call Number listed above and including the catalog record \n (&quot;About This Item&quot;) with your request.\n </p>\n</li>\n\n<li><strong>If there is no information listed in the Reproduction Number field \nabove:</strong> You can generally purchase a quality copy through \nDuplication Services. Cite the Call Number listed above and include the catalog record (&quot;About This Item&quot;) with \n your request.\n</li>\n</ol>\n</p>\n\n<p> \nPrice lists, contact information, and order forms are available on the\n <a href="//lcweb.loc.gov/preserv/pds/">Duplication Services Web site</a>.  \n</p>\n\n\n\n',
#   'resources': [{'caption': 'digital file from original',
#     'files': 1,
#     'image': 'https://tile.loc.gov/storage-services/service/pnp/det/4a20000/4a27000/4a27400/4a27407_150px.jpg',
#     'url': 'https://www.loc.gov/resource/det.4a27407/'}],
#   'shelf_id': 'LC-D418-30816 [P&P]',
#   'site': ['pictures', 'catalog'],
#   'subject': ['dry plate negatives',
#    'chinese americans',
#    'interiors',
#    'narcotics'],
#   'timestamp': '2021-09-04T14:08:19.805Z',
#   'title': '[Chinese Americans in an opium den]',
#   'unrestricted': True,
#   'url': 'https://www.loc.gov/item/2016817917/'},
#  {'access_restricted': False,
#   'aka': ['http://www.loc.gov/pictures/collection/det/item/2016817769/',
#    'http://www.loc.gov/item/2016817769/',
#    'http://www.loc.gov/pictures/item/2016817769/',
#    'http://hdl.loc.gov/loc.pnp/det.4a27230',
#    'http://www.loc.gov/resource/det.4a27230/',
#    'http://lccn.loc.gov/2016817769'],
#   'campaigns': [],
#   'contributor': ['jackson, william henry', 'detroit publishing co.'],
#   'date': '1900',
#   'dates': ['1900-01-01T00:00:00Z'],
#   'description': ['1 negative : glass ; 7 x 5 in.'],
#   'digitized': True,
#   'extract_timestamp': '2021-09-01T22:35:44.834Z',
#   'group': ['det', 'catalog', 'detroit-publishing-company', 'main-catalog'],
#   'hassegments': False,
#   'id': 'http://www.loc.gov/item/2016817769/',
#   'image_url': ['https://tile.loc.gov/storage-services/service/pnp/det/4a20000/4a27000/4a27200/4a27230_150px.jpg#h=150&w=102',
#    'https://tile.loc.gov/storage-services/service/pnp/det/4a20000/4a27000/4a27200/4a27230t.gif#h=150&w=105',
#    'https://tile.loc.gov/storage-services/service/pnp/det/4a20000/4a27000/4a27200/4a27230r.jpg#h=640&w=435',
#    'https://tile.loc.gov/storage-services/service/pnp/det/4a20000/4a27000/4a27200/4a27230v.jpg#h=1024&w=697'],
#   'index': 5,
#   'item': {'call_number': 'LC-D418-9057 [P&P]',
#    'contributor_names': ['Detroit Publishing Co., publisher '],
#    'contributors': ['Jackson, William Henry, 1843-1942, photographer.',
#     'Detroit Publishing Co., publisher.'],
#    'control_number': '2016817769',
#    'created': '2017-11-21T03:42:12Z',
#    'created_published': '[ca. 1900]',
#    'created_published_date': '[ca. 1900]',
#    'creators': [{'link': '//www.loc.gov/pictures/related/?fi=name&q=Jackson%2C%20William%20Henry%2C%201843-1942&co=det',
#      'role': 'photographer',
#      'title': 'Jackson, William Henry, 1843-1942'},
#     {'link': '//www.loc.gov/pictures/related/?fi=name&q=Detroit%20Publishing%20Co.&co=det',
#      'role': 'publisher',
#      'title': 'Detroit Publishing Co.'}],
#    'date': '[ca. 1900]',
#    'digital_id': ['det 4a27230 //hdl.loc.gov/loc.pnp/det.4a27230'],
#    'display_offsite': True,
#    'format': ['still image'],
#    'formats': [{'link': '//www.loc.gov/pictures/related/?fi=format&q=Dry%20plate%20negatives.&co=det',
#      'title': 'Dry plate negatives.'},
#     {'link': '//www.loc.gov/pictures/related/?fi=format&q=Portrait%20photographs.&co=det',
#      'title': 'Portrait photographs.'}],
#    'genre': ['Portrait photographs', 'Dry plate negatives'],
#    'id': '2016817769',
#    'language': ['eng'],
#    'link': '//www.loc.gov/pictures/item/2016817769/',
#    'marc': '//www.loc.gov/pictures/item/2016817769/marc/',
#    'medium': ['1 negative : glass ; 7 x 5 in.'],
#    'medium_brief': '1 negative :',
#    'mediums': ['1 negative : glass ; 7 x 5 in.'],
#    'modified': '2017-11-21T03:42:12Z',
#    'notes': ['Title devised by cataloger.',
#     'Attribution to Jackson and dated based on negative D4-9044.',
#     '"Dup" on negative.',
#     'Detroit Publishing Co. no. 09057.',
#     'Gift; State Historical Society of Colorado; 1949.'],
#    'other_control_numbers': ['20125744', 'det1994023730/PP'],
#    'part_of': 'Detroit Publishing Company photograph collection (Library of Congress)',
#    'repository': 'Library of Congress Prints and Photographs Division Washington, D.C. 20540 USA http://hdl.loc.gov/loc.pnp/pp.print',
#    'reproduction_number': 'LC-DIG-det-4a27230 (digital file from original)',
#    'resource_links': ['//hdl.loc.gov/loc.pnp/det.4a27230'],
#    'rights_advisory': 'No known restrictions on publication.',
#    'rights_information': 'No known restrictions on publication.',
#    'service_low': 'https://tile.loc.gov/storage-services/service/pnp/det/4a20000/4a27000/4a27200/4a27230_150px.jpg',
#    'service_medium': 'https://tile.loc.gov/storage-services/service/pnp/det/4a20000/4a27000/4a27200/4a27230r.jpg',
#    'sort_date': '1900',
#    'source_collection': ['Detroit Publishing Company photograph collection (Library of Congress)'],
#    'source_created': '1994-01-01T00:00:00Z',
#    'source_modified': '2017-11-03T12:07:27Z',
#    'subject_headings': ['Children--Clothing & dress.',
#     'Chinese Americans--Children.'],
#    'subjects': ['Children--Clothing & dress', 'Chinese Americans--Children'],
#    'thumb_gallery': 'https://tile.loc.gov/storage-services/service/pnp/det/4a20000/4a27000/4a27200/4a27230_150px.jpg',
#    'title': '[Chinese American child in embroidered jacket]'},
#   'language': ['english'],
#   'mime_type': ['image/gif', 'image/jpg', 'image/tif'],
#   'number': ['http://www.loc.gov/item/det1994023730/pp',
#    'http://www.loc.gov/item/20125744'],
#   'number_former_id': ['http://www.loc.gov/item/20125744',
#    'http://www.loc.gov/item/det1994023730/pp'],
#   'online_format': ['image'],
#   'original_format': ['photo, print, drawing'],
#   'other_title': [],
#   'partof': ['american memory',
#    'catalog',
#    'detroit publishing company',
#    'prints and photographs division'],
#   'related': {'neighbors': '//www.loc.gov/pictures/related/?&co=det&pk=2016817769&st=gallery&sb=call_number#focus'},
#   'reproductions': '<p>If an image is displaying, you can download it yourself. (Some images \ndisplay only as thumbnails outside the Library of Congress because of rights \nconsiderations, but you have access to larger size images on site.)\n</p>\n\n<p>  \nAlternatively, you can purchase copies of various types through Library \nof Congress Duplication Services</a>.\n</p>\n\n<p> \n<ol>\n<p>\n<li><strong>If a digital image is displaying:</strong> The qualities of the digital image \npartially depend on whether it was made from the original or an \nintermediate such as a copy negative or transparency. If the Reproduction \nNumber field above includes a reproduction number that starts with \nLC-DIG..., then there is a digital image that was made directly \nfrom the original and is of sufficient resolution for most publication\n purposes.\n</li> \n</p>\n\n<li><strong>If there is information listed in the Reproduction Number field above:</strong> \nYou can use the reproduction number to purchase a copy from Duplication \nServices.  It will be made from the source listed in the parentheses after\n the number.  \n<p> \nIf only black-and-white (&quot;b&w&quot;) sources are listed and you \n desire a copy showing color or tint (assuming the original has any), \n you can generally purchase a quality copy of the original in color by \n citing the Call Number listed above and including the catalog record \n (&quot;About This Item&quot;) with your request.\n </p>\n</li>\n\n<li><strong>If there is no information listed in the Reproduction Number field \nabove:</strong> You can generally purchase a quality copy through \nDuplication Services. Cite the Call Number listed above and include the catalog record (&quot;About This Item&quot;) with \n your request.\n</li>\n</ol>\n</p>\n\n<p> \nPrice lists, contact information, and order forms are available on the\n <a href="//lcweb.loc.gov/preserv/pds/">Duplication Services Web site</a>.  \n</p>\n\n\n\n',
#   'resources': [{'caption': 'digital file from original',
#     'files': 1,
#     'image': 'https://tile.loc.gov/storage-services/service/pnp/det/4a20000/4a27000/4a27200/4a27230_150px.jpg',
#     'url': 'https://www.loc.gov/resource/det.4a27230/'}],
#   'shelf_id': 'LC-D418-9057 [P&P]',
#   'site': ['pictures', 'catalog'],
#   'subject': ['dry plate negatives',
#    'chinese americans',
#    'portrait photographs',
#    'children',
#    'clothing & dress'],
#   'timestamp': '2021-09-04T14:08:06.117Z',
#   'title': '[Chinese American child in embroidered jacket]',
#   'unrestricted': True,
#   'url': 'https://www.loc.gov/item/2016817769/'},
#  {'access_restricted': False,
#   'aka': ['http://www.loc.gov/pictures/collection/det/item/2016817768/',
#    'http://www.loc.gov/item/2016817768/',
#    'http://www.loc.gov/pictures/item/2016817768/',
#    'http://hdl.loc.gov/loc.pnp/det.4a27229',
#    'http://www.loc.gov/resource/det.4a27229/',
#    'http://lccn.loc.gov/2016817768'],
#   'campaigns': [],
#   'contributor': ['jackson, william henry', 'detroit publishing co.'],
#   'date': '1901',
#   'dates': ['1901-01-01T00:00:00Z'],
#   'description': ['1 negative : glass ; 7 x 5 in.'],
#   'digitized': True,
#   'extract_timestamp': '2021-09-01T22:35:44.834Z',
#   'group': ['det', 'catalog', 'detroit-publishing-company', 'main-catalog'],
#   'hassegments': False,
#   'id': 'http://www.loc.gov/item/2016817768/',
#   'image_url': ['https://tile.loc.gov/storage-services/service/pnp/det/4a20000/4a27000/4a27200/4a27229_150px.jpg#h=150&w=102',
#    'https://tile.loc.gov/storage-services/service/pnp/det/4a20000/4a27000/4a27200/4a27229t.gif#h=150&w=110',
#    'https://tile.loc.gov/storage-services/service/pnp/det/4a20000/4a27000/4a27200/4a27229r.jpg#h=640&w=435',
#    'https://tile.loc.gov/storage-services/service/pnp/det/4a20000/4a27000/4a27200/4a27229v.jpg#h=1024&w=697'],
#   'index': 6,
#   'item': {'call_number': 'LC-D418-9053 [P&P]',
#    'contributor_names': ['Detroit Publishing Co., copyright claimant ',
#     'Detroit Publishing Co., publisher '],
#    'contributors': ['Jackson, William Henry, 1843-1942, photographer.',
#     'Detroit Publishing Co., copyright claimant, publisher.'],
#    'control_number': '2016817768',
#    'created': '2017-11-21T05:19:27Z',
#    'created_published': 'c1901.',
#    'created_published_date': 'c1901.',
#    'creators': [{'link': '//www.loc.gov/pictures/related/?fi=name&q=Jackson%2C%20William%20Henry%2C%201843-1942&co=det',
#      'role': 'photographer',
#      'title': 'Jackson, William Henry, 1843-1942'},
#     {'link': '//www.loc.gov/pictures/related/?fi=name&q=Detroit%20Publishing%20Co.&co=det',
#      'role': 'copyright claimant',
#      'title': 'Detroit Publishing Co.'},
#     {'link': '//www.loc.gov/pictures/related/?fi=name&q=Detroit%20Publishing%20Co.&co=det',
#      'role': 'publisher',
#      'title': 'Detroit Publishing Co.'}],
#    'date': 'c1901.',
#    'digital_id': ['det 4a27229 //hdl.loc.gov/loc.pnp/det.4a27229'],
#    'display_offsite': True,
#    'format': ['still image'],
#    'formats': [{'link': '//www.loc.gov/pictures/related/?fi=format&q=Dry%20plate%20negatives.&co=det',
#      'title': 'Dry plate negatives.'},
#     {'link': '//www.loc.gov/pictures/related/?fi=format&q=Group%20portraits.&co=det',
#      'title': 'Group portraits.'},
#     {'link': '//www.loc.gov/pictures/related/?fi=format&q=Portrait%20photographs.&co=det',
#      'title': 'Portrait photographs.'}],
#    'genre': ['Group portraits', 'Portrait photographs', 'Dry plate negatives'],
#    'id': '2016817768',
#    'language': ['eng'],
#    'link': '//www.loc.gov/pictures/item/2016817768/',
#    'marc': '//www.loc.gov/pictures/item/2016817768/marc/',
#    'medium': ['1 negative : glass ; 7 x 5 in.'],
#    'medium_brief': '1 negative :',
#    'mediums': ['1 negative : glass ; 7 x 5 in.'],
#    'modified': '2017-11-21T05:19:27Z',
#    'notes': ['Title devised by cataloger.',
#     'Attribution to Jackson based on negative D4-32668.',
#     'Detroit Publishing Co. no. 09053.',
#     'Gift; State Historical Society of Colorado; 1949.'],
#    'other_control_numbers': ['20125743', 'det1994023729/PP'],
#    'part_of': 'Detroit Publishing Company photograph collection (Library of Congress)',
#    'repository': 'Library of Congress Prints and Photographs Division Washington, D.C. 20540 USA http://hdl.loc.gov/loc.pnp/pp.print',
#    'reproduction_number': 'LC-DIG-det-4a27229 (digital file from original)',
#    'resource_links': ['//hdl.loc.gov/loc.pnp/det.4a27229'],
#    'rights_advisory': 'No known restrictions on publication.',
#    'rights_information': 'No known restrictions on publication.',
#    'service_low': 'https://tile.loc.gov/storage-services/service/pnp/det/4a20000/4a27000/4a27200/4a27229_150px.jpg',
#    'service_medium': 'https://tile.loc.gov/storage-services/service/pnp/det/4a20000/4a27000/4a27200/4a27229r.jpg',
#    'sort_date': '1901',
#    'source_collection': ['Detroit Publishing Company photograph collection (Library of Congress)'],
#    'source_created': '1994-01-01T00:00:00Z',
#    'source_modified': '2017-11-03T12:07:25Z',
#    'subject_headings': ['Children--Clothing & dress.',
#     'Chinese Americans--Children.'],
#    'subjects': ['Children--Clothing & dress', 'Chinese Americans--Children'],
#    'thumb_gallery': 'https://tile.loc.gov/storage-services/service/pnp/det/4a20000/4a27000/4a27200/4a27229_150px.jpg',
#    'title': '[Chinese American children in embroidered dress]'},
#   'language': ['english'],
#   'mime_type': ['image/gif', 'image/jpg', 'image/tif'],
#   'number': ['http://www.loc.gov/item/det1994023729/pp',
#    'http://www.loc.gov/item/20125743'],
#   'number_former_id': ['http://www.loc.gov/item/20125743',
#    'http://www.loc.gov/item/det1994023729/pp'],
#   'online_format': ['image'],
#   'original_format': ['photo, print, drawing'],
#   'other_title': [],
#   'partof': ['american memory',
#    'catalog',
#    'detroit publishing company',
#    'prints and photographs division'],
#   'related': {'neighbors': '//www.loc.gov/pictures/related/?&co=det&pk=2016817768&st=gallery&sb=call_number#focus'},
#   'reproductions': '<p>If an image is displaying, you can download it yourself. (Some images \ndisplay only as thumbnails outside the Library of Congress because of rights \nconsiderations, but you have access to larger size images on site.)\n</p>\n\n<p>  \nAlternatively, you can purchase copies of various types through Library \nof Congress Duplication Services</a>.\n</p>\n\n<p> \n<ol>\n<p>\n<li><strong>If a digital image is displaying:</strong> The qualities of the digital image \npartially depend on whether it was made from the original or an \nintermediate such as a copy negative or transparency. If the Reproduction \nNumber field above includes a reproduction number that starts with \nLC-DIG..., then there is a digital image that was made directly \nfrom the original and is of sufficient resolution for most publication\n purposes.\n</li> \n</p>\n\n<li><strong>If there is information listed in the Reproduction Number field above:</strong> \nYou can use the reproduction number to purchase a copy from Duplication \nServices.  It will be made from the source listed in the parentheses after\n the number.  \n<p> \nIf only black-and-white (&quot;b&w&quot;) sources are listed and you \n desire a copy showing color or tint (assuming the original has any), \n you can generally purchase a quality copy of the original in color by \n citing the Call Number listed above and including the catalog record \n (&quot;About This Item&quot;) with your request.\n </p>\n</li>\n\n<li><strong>If there is no information listed in the Reproduction Number field \nabove:</strong> You can generally purchase a quality copy through \nDuplication Services. Cite the Call Number listed above and include the catalog record (&quot;About This Item&quot;) with \n your request.\n</li>\n</ol>\n</p>\n\n<p> \nPrice lists, contact information, and order forms are available on the\n <a href="//lcweb.loc.gov/preserv/pds/">Duplication Services Web site</a>.  \n</p>\n\n\n\n',
#   'resources': [{'caption': 'digital file from original',
#     'files': 1,
#     'image': 'https://tile.loc.gov/storage-services/service/pnp/det/4a20000/4a27000/4a27200/4a27229_150px.jpg',
#     'url': 'https://www.loc.gov/resource/det.4a27229/'}],
#   'shelf_id': 'LC-D418-9053 [P&P]',
#   'site': ['pictures', 'catalog'],
#   'subject': ['portrait photographs',
#    'dry plate negatives',
#    'chinese americans',
#    'clothing & dress',
#    'group portraits',
#    'children'],
#   'timestamp': '2021-09-04T14:08:06.117Z',
#   'title': '[Chinese American children in embroidered dress]',
#   'unrestricted': True,
#   'url': 'https://www.loc.gov/item/2016817768/'},
#  {'access_restricted': False,
#   'aka': ['http://www.loc.gov/item/powmia/pwmaster_110775/',
#    'http://www.loc.gov/resource/powmia/pwmaster_110775/'],
#   'campaigns': [],
#   'contributor': ['joint casualty resolution center'],
#   'contributor_originator': ['joint casualty resolution center'],
#   'date': '1980-08-08',
#   'dates': ['1980-08-08T00:00:00Z', '1973-01-01T00:00:00Z'],
#   'description': ['post-1975 Vietnam / IIRN I80-019'],
#   'digitized': True,
#   'extract_timestamp': '2022-12-16T14:19:30.546Z',
#   'group': ['powmia'],
#   'hassegments': False,
#   'id': 'http://www.loc.gov/item/powmia/pwmaster_110775/',
#   'image_url': ['https://tile.loc.gov/storage-services/service/frd/pwmia/357/110775.gif'],
#   'index': 7,
#   'item': {'comments': 'MESSAGES 092135ZAPR81-DIA AND 060151ZMAY81-USDAO BANGKOK INCLUDED',
#    'country': ['post-1975 Vietnam'],
#    'date_of_information': ['1973-01-01'],
#    'date_of_report': ['1980-08-08'],
#    'date_time_group': [None],
#    'document_id': 'PWMASTER_110775',
#    'originator': 'JOINT CASUALTY RESOLUTION CENTER, ???',
#    'pages': '45-49',
#    'reel': ['357'],
#    'source_number': [''],
#    'type': ['refugee report']},
#   'location': ['post-1975 vietnam'],
#   'mime_type': ['application/pdf'],
#   'number': ['i80-019', 'none', 'http://www.loc.gov/item/powmia/pw042036'],
#   'number_former_id': ['http://www.loc.gov/item/powmia/pw042036'],
#   'number_iirn': ['i80-019'],
#   'number_refno': ['none'],
#   'online_format': ['pdf'],
#   'original_format': ['manuscript/mixed material'],
#   'other_title': [],
#   'partof': ['357',
#    'defense pow/mia accounting agency',
#    'federal research division',
#    'vietnam-era prisoner-of-war/missing-in-action database'],
#   'partof_reel': ['357'],
#   'resources': [{'pdf': 'https://tile.loc.gov/storage-services/service//frd/pwmia/357/110775.pdf',
#     'url': 'https://www.loc.gov/item/powmia/pwmaster_110775/'}],
#   'shelf_id': 'http://www.loc.gov/item/powmia/pwmaster_110775/',
#   'timestamp': '2022-12-16T14:25:58.069Z',
#   'title': 'CHINESE AMERICAN STILL IN SAIGON. EVALUATION',
#   'type': 'manuscript/mixed material',
#   'url': 'https://www.loc.gov/item/powmia/pwmaster_110775/'},
#  {'access_restricted': False,
#   'aka': ['http://www.loc.gov/item/powmia/pwmaster_6500/',
#    'http://www.loc.gov/resource/powmia/pwmaster_6500/'],
#   'campaigns': [],
#   'contributor': ['defense intelligence agency'],
#   'contributor_originator': ['defense intelligence agency'],
#   'date': '1980-10-14',
#   'dates': ['1980-10-14T00:00:00Z', '1980-08-01T00:00:00Z'],
#   'description': ['Post-1975 Vietnam / DTG 141651ZOCT80'],
#   'digitized': True,
#   'extract_timestamp': '2022-12-16T14:15:56.695Z',
#   'group': ['powmia'],
#   'hassegments': False,
#   'id': 'http://www.loc.gov/item/powmia/pwmaster_6500/',
#   'image_url': ['https://tile.loc.gov/storage-services/service/frd/pwmia/18/6500.gif'],
#   'index': 8,
#   'item': {'category': 'Source Report',
#    'country': ['Post-1975 Vietnam'],
#    'date_of_information': ['1980-08-01'],
#    'date_of_report': ['1980-10-14'],
#    'date_time_group': ['141651ZOCT80'],
#    'document_id': 'PWMASTER_6500',
#    'keywords': ['Live sighting', 'Saigon'],
#    'names': ['Van, To'],
#    'originator': 'DEFENSE INTELLIGENCE AGENCY',
#    'pages': '16',
#    'reel': ['18'],
#    'source_number': ['0833'],
#    'type': ['message']},
#   'location': ['post-1975 vietnam'],
#   'mime_type': ['application/pdf'],
#   'number': ['none', 'http://www.loc.gov/item/powmia/pw038994'],
#   'number_former_id': ['http://www.loc.gov/item/powmia/pw038994'],
#   'number_refno': ['none'],
#   'online_format': ['pdf'],
#   'original_format': ['manuscript/mixed material'],
#   'other_title': [],
#   'partof': ['defense pow/mia accounting agency',
#    'source report',
#    '18',
#    'federal research division',
#    'vietnam-era prisoner-of-war/missing-in-action database'],
#   'partof_category': ['source report'],
#   'partof_reel': ['18'],
#   'resources': [{'pdf': 'https://tile.loc.gov/storage-services/service//frd/pwmia/18/6500.pdf',
#     'url': 'https://www.loc.gov/item/powmia/pwmaster_6500/'}],
#   'shelf_id': 'http://www.loc.gov/item/powmia/pwmaster_6500/',
#   'subject': ['saigon', 'live sighting', 'van, to'],
#   'subject_name': ['van, to'],
#   'timestamp': '2022-12-16T14:55:47.946Z',
#   'title': 'REFUGEE REPORT, CHINESE AMERICAN STILL IN SAIGON',
#   'type': 'manuscript/mixed material',
#   'url': 'https://www.loc.gov/item/powmia/pwmaster_6500/'},
#  {'access_restricted': False,
#   'aka': ['http://www.loc.gov/pictures/collection/ffcarp/item/2006691451/',
#    'http://www.loc.gov/item/2006691451/',
#    'http://www.loc.gov/pictures/item/2006691451/',
#    'http://hdl.loc.gov/loc.pnp/cph.3c37034',
#    'http://www.loc.gov/resource/cph.3c37034/',
#    'http://lccn.loc.gov/2006691451'],
#   'campaigns': [],
#   'coordinates': ['40.3199737,116.2173569'],
#   'date': '1900',
#   'description': ['1 photographic print. | Photograph shows U.S. Marines in formation on the grounds of the U.S. Legation, Beijing, China.'],
#   'digitized': True,
#   'extract_timestamp': '2021-09-01T22:59:14.016Z',
#   'group': ['ffcarp', 'catalog', 'carpenter', 'main-catalog'],
#   'hassegments': False,
#   'id': 'http://www.loc.gov/item/2006691451/',
#   'image_url': ['https://tile.loc.gov/storage-services/service/pnp/cph/3c30000/3c37000/3c37000/3c37034_150px.jpg',
#    'https://tile.loc.gov/storage-services/service/pnp/cph/3c30000/3c37000/3c37000/3c37034_150px.jpg#h=121&w=150',
#    'https://tile.loc.gov/storage-services/service/pnp/cph/3c30000/3c37000/3c37000/3c37034t.gif#h=121&w=150',
#    'https://tile.loc.gov/storage-services/service/pnp/cph/3c30000/3c37000/3c37000/3c37034r.jpg#h=516&w=640',
#    'https://tile.loc.gov/storage-services/service/pnp/cph/3c30000/3c37000/3c37000/3c37034v.jpg#h=825&w=1024'],
#   'index': 9,
#   'item': {'call_number': 'LOT 11356-1 [item] [P&P]',
#    'control_number': '2006691451',
#    'created': '2016-04-21 07:29:45',
#    'created_published': '[ca. 1900]',
#    'created_published_date': '[ca. 1900]',
#    'date': '[ca. 1900]',
#    'digital_id': ['cph 3c37034 //hdl.loc.gov/loc.pnp/cph.3c37034'],
#    'display_offsite': True,
#    'format': ['still image'],
#    'formats': [{'link': '//www.loc.gov/pictures/related/?fi=format&q=Photographic%20prints--1890-1910.&co=ffcarp',
#      'title': 'Photographic prints--1890-1910.'}],
#    'id': '2006691451',
#    'link': '//www.loc.gov/pictures/item/2006691451/',
#    'location': ['China--Beijing'],
#    'marc': '//www.loc.gov/pictures/item/2006691451/marc/',
#    'medium': ['1 photographic print.'],
#    'medium_brief': '1 photographic print.',
#    'mediums': ['1 photographic print.'],
#    'modified': '2016-04-21 07:29:46',
#    'notes': ['Title from item.',
#     'Forms part of: Frank and Frances Carpenter Collection (Library of Congress).'],
#    'place': [{'latitude': '',
#      'link': '//www.loc.gov/pictures/related/?fi=place&q=China--Beijing&co=ffcarp',
#      'longitude': '',
#      'title': 'China--Beijing'}],
#    'repository': 'Library of Congress Prints and Photographs Division Washington, D.C. 20540 USA',
#    'reproduction_number': 'LC-USZ62-137034 (b&w film copy neg.)',
#    'resource_links': ['//hdl.loc.gov/loc.pnp/cph.3c37034'],
#    'rights_advisory': 'No known restrictions on publication.',
#    'rights_information': 'No known restrictions on publication.',
#    'service_low': 'https://tile.loc.gov/storage-services/service/pnp/cph/3c30000/3c37000/3c37000/3c37034_150px.jpg',
#    'service_medium': 'https://tile.loc.gov/storage-services/service/pnp/cph/3c30000/3c37000/3c37000/3c37034r.jpg',
#    'sort_date': '1900',
#    'source_created': '2006-10-25 00:00:00',
#    'source_modified': '2006-10-27 11:34:45',
#    'subject_headings': ['United States.--Marine Corps--1890-1910.',
#     'Government facilities--American--China--Beijing--1890-1910.',
#     'Marines (Military personnel)--1890-1910.',
#     'China--Beijing'],
#    'subjects': ['United States.--Marine Corps--1890-1910',
#     'Government facilities--American--China--Beijing--1890-1910',
#     'Marines (Military personnel)--1890-1910'],
#    'summary': 'Photograph shows U.S. Marines in formation on the grounds of the U.S. Legation, Beijing, China.',
#    'thumb_gallery': 'https://tile.loc.gov/storage-services/service/pnp/cph/3c30000/3c37000/3c37000/3c37034_150px.jpg',
#    'title': 'China -  Peking. American Legation'},
#   'language': ['english'],
#   'latlong': [40.3199737, 116.2173569],
#   'location': ['beijing', 'china'],
#   'location_str': '',
#   'locations': [[{'geometry': ['type', 'coordinates'],
#      'properties': ['is_composite',
#       'name',
#       'area',
#       'importance',
#       'is_primary',
#       'alternate',
#       'id',
#       'admin',
#       'feature_code',
#       'feature_code_name',
#       'timeframe',
#       'uris',
#       'population'],
#      'type': 'Feature'}]],
#   'lonlat': [116.2173569, 40.3199737],
#   'mime_type': ['image/gif', 'image/jpg', 'image/tif', 'image/jpeg'],
#   'online_format': ['image'],
#   'original_format': ['photo, print, drawing'],
#   'other_title': [],
#   'partof': ['lot 11356',
#    'catalog',
#    'carpenter collection',
#    'prints and photographs division'],
#   'related': {'group_record': '//www.loc.gov/pictures/search/?q=LOT 11356&fi=number&op=PHRASE&va=exact&co=coll&sg=true',
#    'neighbors': '//www.loc.gov/pictures/related/?&co=ffcarp&pk=2006691451&st=gallery&sb=call_number#focus'},
#   'reproductions': '<p>If an image is displaying, you can download it yourself. (Some images \r\ndisplay only as thumbnails outside the Library of Congress because of rights \r\nconsiderations, but you have access to larger size images on site.)\r\n</p>\r\n\r\n<p>  \r\nAlternatively, you can purchase copies of various types through Library \r\nof Congress Duplication Services</a>.\r\n</p>\r\n\r\n<p> \r\n<ol>\r\n<p>\r\n<li><strong>If a digital image is displaying:</strong> The qualities of the digital image \r\npartially depend on whether it was made from the original or an \r\nintermediate such as a copy negative or transparency. If the Reproduction \r\nNumber field above includes a reproduction number that starts with \r\nLC-DIG..., then there is a digital image that was made directly \r\nfrom the original and is of sufficient resolution for most publication\r\n purposes.\r\n</li> \r\n</p>\r\n\r\n<li><strong>If there is information listed in the Reproduction Number field above:</strong> \r\nYou can use the reproduction number to purchase a copy from Duplication \r\nServices.  It will be made from the source listed in the parentheses after\r\n the number.  \r\n<p> \r\nIf only black-and-white (&quot;b&w&quot;) sources are listed and you \r\n desire a copy showing color or tint (assuming the original has any), \r\n you can generally purchase a quality copy of the original in color by \r\n citing the Call Number listed above and including the catalog record \r\n (&quot;About This Item&quot;) with your request.\r\n </p>\r\n</li>\r\n\r\n<li><strong>If there is no information listed in the Reproduction Number field \r\nabove:</strong> You can generally purchase a quality copy through \r\nDuplication Services. Cite the Call Number listed above and include the catalog record (&quot;About This Item&quot;) with \r\n your request.\r\n</li>\r\n</ol>\r\n</p>\r\n\r\n<p> \r\nPrice lists, contact information, and order forms are available on the\r\n <a href="//lcweb.loc.gov/preserv/pds/">Duplication Services Web site</a>.  \r\n</p>\r\n\r\n\r\n\r\n',
#   'resources': [{'caption': 'digital file from b&w film copy neg.',
#     'files': 1,
#     'image': 'https://tile.loc.gov/storage-services/service/pnp/cph/3c30000/3c37000/3c37000/3c37034_150px.jpg',
#     'url': 'https://www.loc.gov/resource/cph.3c37034/'}],
#   'shelf_id': 'LOT 11356-1 [item] [P&P]',
#   'site': ['pictures', 'catalog'],
#   'subject': ['beijing',
#    'marines (military personnel)',
#    'government facilities',
#    'photographic prints',
#    'united states',
#    'marine corps',
#    'american',
#    'china'],
#   'timestamp': '2021-09-04T12:38:48.603Z',
#   'title': 'China -  Peking. American Legation',
#   'unrestricted': True,
#   'url': 'https://www.loc.gov/item/2006691451/'},
#  {'access_restricted': False,
#   'aka': ['https://www.loc.gov/pictures/item/2015650748/',
#    'http://www.loc.gov/item/2015650748/',
#    'http://www.loc.gov/pictures/item/2015650748/',
#    'https://www.loc.gov/pictures/collection/cph/item/2015650748/',
#    'http://www.loc.gov/pictures/collection/cph/item/2015650748/',
#    'http://www.loc.gov/resource/ds.07749/',
#    'http://hdl.loc.gov/loc.pnp/ds.07749',
#    'http://lccn.loc.gov/2015650748'],
#   'campaigns': [],
#   'contributor': ['genthe, arnold'],
#   'date': '1896',
#   'dates': ['1896-01-01T00:00:00Z'],
#   'description': ['1 photograph : gelatin silver print ; sheet 26 x 21 cm (8 x 10 format) | Photograph shows Chinese American woman and girl in traditional dress standing on a street in Chinatown, San Francisco.'],
#   'digitized': True,
#   'extract_timestamp': '2021-08-27T19:13:50.677Z',
#   'group': ['cph',
#    'catalog',
#    'miscellaneous-items-high-demand',
#    'main-catalog'],
#   'hassegments': False,
#   'id': 'http://www.loc.gov/item/2015650748/',
#   'image_url': ['https://tile.loc.gov/storage-services/service/pnp/ds/07700/07749_150px.jpg#h=150&w=121',
#    'https://tile.loc.gov/storage-services/service/pnp/ds/07700/07749r.jpg#h=640&w=518',
#    'https://tile.loc.gov/storage-services/service/pnp/ds/07700/07749v.jpg#h=1024&w=828'],
#   'index': 10,
#   'item': {'access_advisory': 'Please allow fourteen days advance notice to view materials. For information see "Access to Unprocessed Materials," https://www.loc.gov/rr/print/info/022_unpr.html',
#    'call_number': 'Unprocessed in PR 06 CN 347 [item] [P&P]',
#    'contributors': ['Genthe, Arnold, 1869-1942, photographer.'],
#    'control_number': '2015650748',
#    'created': '2016-04-20T07:23:16Z',
#    'created_published': '[between 1896 and 1911, printed later]',
#    'created_published_date': '[between 1896 and 1911, printed later]',
#    'creators': [{'link': 'https://www.loc.gov/pictures/related/?fi=name&q=Genthe%2C%20Arnold%2C%201869-1942&co=cph',
#      'role': 'photographer',
#      'title': 'Genthe, Arnold, 1869-1942'}],
#    'date': '[between 1896 and 1911, printed later]',
#    'digital_id': ['ds 07749 //hdl.loc.gov/loc.pnp/ds.07749'],
#    'display_offsite': True,
#    'format': ['still image'],
#    'formats': [{'link': 'https://www.loc.gov/pictures/related/?fi=format&q=Photographic%20prints--1890-1920.&co=cph',
#      'title': 'Photographic prints--1890-1920.'}],
#    'genre': ['Photographic prints--1890-1920'],
#    'id': '2015650748',
#    'language': ['eng'],
#    'link': 'https://www.loc.gov/pictures/item/2015650748/',
#    'location': ['California--San Francisco',
#     'Chinatown (San Francisco, Calif.)'],
#    'marc': 'https://www.loc.gov/pictures/item/2015650748/marc/',
#    'medium': ['1 photograph : gelatin silver print ; sheet 26 x 21 cm (8 x 10 format)'],
#    'medium_brief': '1 photograph :',
#    'mediums': ['1 photograph : gelatin silver print ; sheet 26 x 21 cm (8 x 10 format)'],
# ...
#    'https://tile.loc.gov/storage-services/service/pnp/fsa/8d21000/8d21900/8d21942t.gif#h=150&w=145',
#    'https://tile.loc.gov/storage-services/service/pnp/fsa/8d21000/8d21900/8d21942r.jpg#h=640&w=615',
#    'https://tile.loc.gov/storage-services/service/pnp/fsa/8d21000/8d21900/8d21942v.jpg#h=1024&w=983'],
#   'index': 24,
#   'item': {'call_number': 'LC-USW3- 007282-E [P&P] LOT 244 (corresponding photographic print)',
#    'contributors': ['Collins, Marjory, 1912-1985, photographer.'],
#    'control_number': '2017835792',
#    'created': '2017-09-26T03:35:39Z',
#    'created_published': '1942 Aug.?',
#    'created_published_date': '1942 Aug.?',
#    'creators': [{'link': '//www.loc.gov/pictures/related/?fi=name&q=Collins%2C%20Marjory%2C%201912-1985&co=fsa',
#      'role': 'photographer',
#      'title': 'Collins, Marjory, 1912-1985'}],
#    'date': '1942 Aug.?',
#    'digital_id': ['fsa 8d21942 //hdl.loc.gov/loc.pnp/fsa.8d21942'],
#    'display_offsite': True,
#    'format': ['still image'],
#    'formats': [{'link': '//www.loc.gov/pictures/related/?fi=format&q=Nitrate%20negatives.&co=fsa',
#      'title': 'Nitrate negatives.'}],
#    'genre': ['Nitrate negatives'],
#    'id': '2017835792',
#    'language': ['eng'],
#    'link': '//www.loc.gov/pictures/item/2017835792/',
#    'marc': '//www.loc.gov/pictures/item/2017835792/marc/',
#    'medium': ['1 negative : nitrate ; 2 1/4 x 2 1/4 inches or smaller.'],
#    'medium_brief': '1 negative :',
#    'mediums': ['1 negative : nitrate ; 2 1/4 x 2 1/4 inches or smaller.'],
#    'modified': '2017-09-26T03:35:39Z',
#    'notes': ['Title and other information from caption card.',
#     'Transfer; United States. Office of War Information. Overseas Picture Division. Washington Division; 1944.',
#     'More information about the FSA/OWI Collection is available at http://hdl.loc.gov/loc.pnp/pp.fsaowi',
#     'Temp. note: owibatch2',
#     'Film copy on SIS roll 11, frame 66.'],
#    'other_control_numbers': ['20007463', 'owi2001009522/PP'],
#    'other_number': 'D 922',
#    'part_of': 'Farm Security Administration - Office of War Information photograph collection (Library of Congress)',
#    'place': [{'latitude': '',
#      'link': '//www.loc.gov/pictures/related/?fi=place&q=New%20York%20%28State%29--New%20York&co=fsa',
#      'longitude': '',
#      'title': 'New York (State)--New York'}],
#    'repository': 'Library of Congress Prints and Photographs Division Washington, D.C. 20540 USA http://hdl.loc.gov/loc.pnp/pp.print',
#    'reproduction_number': 'LC-DIG-fsa-8d21942 (digital file from original neg.)\nLC-USW3-007282-E (b&w film nitrate neg.)',
#    'resource_links': ['//hdl.loc.gov/loc.pnp/fsa.8d21942'],
#    'rights_advisory': 'No known restrictions. For information, see U.S. Farm Security Administration/Office of War Information Black & White Photographs https://www.loc.gov/rr/print/res/071_fsab.html',
#    'rights_information': 'No known restrictions. For information, see U.S. Farm Security Administration/Office of War Information Black & White Photographs https://www.loc.gov/rr/print/res/071_fsab.html',
#    'service_low': 'https://tile.loc.gov/storage-services/service/pnp/fsa/8d21000/8d21900/8d21942_150px.jpg',
#    'service_medium': 'https://tile.loc.gov/storage-services/service/pnp/fsa/8d21000/8d21900/8d21942r.jpg',
#    'sort_date': '1942',
#    'source_collection': ['Farm Security Administration - Office of War Information photograph collection (Library of Congress)'],
#    'source_created': '2001-08-02T00:00:00Z',
#    'source_modified': '2017-09-19T14:45:05Z',
#    'subject_headings': ['United States--New York (State)--New York.',
#     'New York (State)--New York'],
#    'subjects': ['United States--New York (State)--New York'],
#    'thumb_gallery': 'https://tile.loc.gov/storage-services/service/pnp/fsa/8d21000/8d21900/8d21942_150px.jpg',
#    'title': 'New York, New York. Chinese-American in his home in Flatbush'},
#   'language': ['english'],
#   'location': ['united states', 'new york', 'new york (state)'],
#   'location_city': ['new york'],
#   'location_country': ['united states'],
#   'location_state': ['new york (state)'],
#   'mime_type': ['image/gif', 'image/jpg', 'image/tif'],
#   'number': ['http://www.loc.gov/item/20007463',
#    'http://www.loc.gov/item/owi2001009522/pp'],
#   'number_former_id': ['http://www.loc.gov/item/20007463',
#    'http://www.loc.gov/item/owi2001009522/pp'],
#   'online_format': ['image'],
#   'original_format': ['photo, print, drawing'],
#   'other_title': [],
#   'partof': ['american memory',
#    'lot 244',
#    'catalog',
#    'prints and photographs division',
#    'farm security administration/office of war information black-and-white negatives'],
#   'related': {'group_record': '//www.loc.gov/pictures/search/?q=LOT 244&fi=number&op=PHRASE&va=exact&co=coll&sg=true',
#    'neighbors': '//www.loc.gov/pictures/related/?&co=fsa&pk=2017835792&st=gallery&sb=call_number#focus'},
#   'reproductions': '<p>\n    If an image is displaying, you can download it yourself. (Some images \n    display only as thumbnails outside the Library of Congress because of rights \n    considerations, but you have access to larger size images on site.)\n</p>\n<p>\nAlternatively, you can purchase copies of various types through Library \nof Congress Duplication Services</a>.\n</p>\n<p>\n    <ol>\n        <p>\n            <li>\n                <strong>If a digital image is displaying:</strong>\n                The qualities of the digital image \n                partially depend on whether it was made from the original or an  \n                intermediate such as a copy negative or transparency. If the Reproduction \n                Number field above includes a reproduction number that starts with  \n                LC-DIG..., then there is a digital image that was made directly \n                from the original and is of sufficient resolution for most publication\n                purposes.\n            </li>\n        </p>\n        <li>\n            <strong>If there is information listed in the Reproduction Number field above:</strong>\n            You can use the reproduction number to purchase a copy from Duplication \n            Services.  It will be made from the source listed in the parentheses after  \n            the number. \n            <table width="75%" border="1" align="center" cellpadding="1" bordercolor="#993333">\n                <tr>\n                    <td>\n                        <p>\n                            <strong>\n                                <center>\n                                    Expect\n                                    Delays in Service of Nitrate Negatives\n                                </center>\n                            </strong>\n                        </p>\n\t\t\t\t\t\t\n<p>\t\t\t\t\t\t\nReproductions of all types are available, but Duplication Services anticipates an \n8-10 week turnaround in completing orders, as all negatives must be reproduced at \ntheir off-site, cold storage facility.\n</p>\n<p>\nClues that an FSA/OWI/OEM image may be affected are:<br />\n<strong>Medium</strong> field says "1 negative : nitrate" OR <br />\n<strong>Reproduction Number</strong> field begins with: LC-USF33- \n</p>\n              \n                        <p>\n                            If either is the case, you may wish to consult\n                            with Prints and Photographs Division reference staff\n                            (202-707-6394). In certain instances, duplicate\n                            negatives are available for copying.\n                        </p>\n                    </td>\n                </tr>\n            </table>\n            <p>\n                If only black-and-white (&quot;b&w&quot;) sources are listed and you \n                desire a copy showing color or tint (assuming the original has any),  \n                you can generally purchase a quality copy of the original in color by \n                citing the Call Number listed above and including the catalog record \n                (&quot;About This Item&quot;) with your request.\n            </p>\n        </li>\n        <li>\n            <strong>If there is no information listed in the Reproduction Number field \n                above:</strong>\n            You can generally purchase a quality copy through \n            Duplication Services. Cite the Call Number listed above and include the catalog record (&quot;About This Item&quot;) with \n            your request.\n        </li>\n    </ol>\n</p>\n<p>\n    Price lists, contact information, and order forms are available on the<a href="//lcweb.loc.gov/preserv/pds/">Duplication Services Web site</a>. \n</p>\n',
#   'resources': [{'caption': 'digital file from original neg.',
#     'files': 1,
#     'image': 'https://tile.loc.gov/storage-services/service/pnp/fsa/8d21000/8d21900/8d21942_150px.jpg',
#     'url': 'https://www.loc.gov/resource/fsa.8d21942/'}],
#   'shelf_id': 'LC-USW3- 007282-E [P&P] LOT 244 (corresponding photographic print)',
#   'site': ['pictures', 'catalog'],
#   'subject': ['united states',
#    'new york',
#    'nitrate negatives',
#    'new york (state)'],
#   'timestamp': '2021-09-04T15:52:26.732Z',
#   'title': 'New York, New York. Chinese-American in his home in Flatbush',
#   'unrestricted': True,
#   'url': 'https://www.loc.gov/item/2017835792/'},
#  {'access_restricted': False,
#   'aka': ['http://www.loc.gov/pictures/collection/ggbain/item/2001704343/',
#    'http://www.loc.gov/item/2001704343/',
#    'http://www.loc.gov/pictures/item/2001704343/',
#    'http://hdl.loc.gov/loc.pnp/cph.3a31112',
#    'http://www.loc.gov/resource/cph.3a31112/',
#    'http://lccn.loc.gov/2001704343'],
#   'campaigns': [],
#   'date': '1909',
#   'dates': ['1909-01-01T00:00:00Z'],
#   'description': ['1 photographic print.'],
#   'digitized': True,
#   'extract_timestamp': '2021-09-01T22:14:29.137Z',
#   'group': ['ggbain', 'catalog', 'bain', 'main-catalog'],
#   'hassegments': False,
#   'id': 'http://www.loc.gov/item/2001704343/',
#   'image_url': ['https://tile.loc.gov/storage-services/service/pnp/cph/3a30000/3a31000/3a31100/3a31112_150px.jpg',
#    'https://tile.loc.gov/storage-services/service/pnp/cph/3a30000/3a31000/3a31100/3a31112_150px.jpg#h=109&w=150',
#    'https://tile.loc.gov/storage-services/service/pnp/cph/3a30000/3a31000/3a31100/3a31112t.gif#h=109&w=150',
#    'https://tile.loc.gov/storage-services/service/pnp/cph/3a30000/3a31000/3a31100/3a31112r.jpg#h=465&w=640'],
#   'index': 25,
#   'item': {'call_number': 'LOT 7178 [item] [P&P]',
#    'control_number': '2001704343',
#    'created': '2016-04-21T02:42:00Z',
#    'created_published': '[between 1909 and 1913]',
#    'created_published_date': '[between 1909 and 1913]',
#    'date': '[between 1909 and 1913]',
#    'digital_id': ['cph 3a31112 //hdl.loc.gov/loc.pnp/cph.3a31112'],
#    'display_offsite': True,
#    'format': ['still image'],
#    'formats': [{'link': '//www.loc.gov/pictures/related/?fi=format&q=Photographic%20prints--1900-1920.&co=ggbain',
#      'title': 'Photographic prints--1900-1920.'}],
#    'id': '2001704343',
#    'language': ['eng'],
#    'link': '//www.loc.gov/pictures/item/2001704343/',
#    'location': ['Chinatown (New York, N.Y.)'],
#    'marc': '//www.loc.gov/pictures/item/2001704343/marc/',
#    'medium': ['1 photographic print.'],
#    'medium_brief': '1 photographic print.',
#    'mediums': ['1 photographic print.'],
#    'modified': '2016-04-21T02:42:00Z',
#    'notes': ['Title and other information transcribed from caption card and item.',
#     'George Grantham Bain Collection (Library of Congress).'],
#    'other_control_numbers': ['12608220'],
#    'place': [{'latitude': '',
#      'link': '//www.loc.gov/pictures/related/?fi=place&q=Chinatown%20%28New%20York%2C%20N.Y.%29&co=ggbain',
#      'longitude': '',
#      'title': 'Chinatown (New York, N.Y.)'}],
#    'repository': 'Library of Congress Prints and Photographs Division Washington, D.C. 20540 USA',
#    'reproduction_number': 'LC-USZ62-30443 (b&w film copy neg.)',
#    'resource_links': ['//hdl.loc.gov/loc.pnp/cph.3a31112'],
#    'rights_advisory': 'No known restrictions on reproduction.',
#    'rights_information': 'No known restrictions on reproduction.',
#    'service_low': 'https://tile.loc.gov/storage-services/service/pnp/cph/3a30000/3a31000/3a31100/3a31112_150px.jpg',
#    'service_medium': 'https://tile.loc.gov/storage-services/service/pnp/cph/3a30000/3a31000/3a31100/3a31112r.jpg',
#    'sort_date': '1909',
#    'source_created': '2001-12-04T00:00:00Z',
#    'source_modified': '2005-02-08T09:36:52Z',
#    'subject_headings': ['Chinatown (New York, N.Y.)--1900-1920.',
#     'Chinatown (New York, N.Y.)'],
#    'subjects': ['Chinatown (New York, N.Y.)--1900-1920'],
#    'thumb_gallery': 'https://tile.loc.gov/storage-services/service/pnp/cph/3a30000/3a31000/3a31100/3a31112_150px.jpg',
#    'title': '[Chinese-American father and daughter making New Year calls, Chinatown, New York City]'},
#   'language': ['english'],
#   'location': ['new york', 'chinatown'],
#   'mime_type': ['image/gif', 'image/jpg', 'image/tif', 'image/jpeg'],
#   'number': ['http://www.loc.gov/item/12608220'],
#   'number_former_id': ['http://www.loc.gov/item/12608220'],
#   'online_format': ['image'],
#   'original_format': ['photo, print, drawing'],
#   'other_title': [],
#   'partof': ['bain collection',
#    'catalog',
#    'lot 7178',
#    'prints and photographs division'],
#   'related': {'group_record': '//www.loc.gov/pictures/search/?q=LOT 7178&fi=number&op=PHRASE&va=exact&co=coll&sg=true',
#    'neighbors': '//www.loc.gov/pictures/related/?&co=ggbain&pk=2001704343&st=gallery&sb=call_number#focus'},
#   'reproductions': '<p>If an image is displaying, you can download it yourself. (Some images \ndisplay only as thumbnails outside the Library of Congress because of rights \nconsiderations, but you have access to larger size images on site.)\n</p>\n\n<p>  \nAlternatively, you can purchase copies of various types through Library \nof Congress Duplication Services</a>.\n</p>\n\n<p> \n<ol>\n<p>\n<li><strong>If a digital image is displaying:</strong> The qualities of the digital image \npartially depend on whether it was made from the original or an \nintermediate such as a copy negative or transparency. If the Reproduction \nNumber field above includes a reproduction number that starts with \nLC-DIG..., then there is a digital image that was made directly \nfrom the original and is of sufficient resolution for most publication\n purposes.\n</li> \n</p>\n\n<li><strong>If there is information listed in the Reproduction Number field above:</strong> \nYou can use the reproduction number to purchase a copy from Duplication \nServices.  It will be made from the source listed in the parentheses after\n the number.  \n<p> \nIf only black-and-white (&quot;b&w&quot;) sources are listed and you \n desire a copy showing color or tint (assuming the original has any), \n you can generally purchase a quality copy of the original in color by \n citing the Call Number listed above and including the catalog record \n (&quot;About This Item&quot;) with your request.\n </p>\n</li>\n\n<li><strong>If there is no information listed in the Reproduction Number field \nabove:</strong> You can generally purchase a quality copy through \nDuplication Services. Cite the Call Number listed above and include the catalog record (&quot;About This Item&quot;) with \n your request.\n</li>\n</ol>\n</p>\n\n<p> \nPrice lists, contact information, and order forms are available on the\n <a href="//lcweb.loc.gov/preserv/pds/">Duplication Services Web site</a>.  \n</p>\n\n\n\n',
#   'resources': [{'caption': 'b&w film copy neg.',
#     'files': 1,
#     'image': 'https://tile.loc.gov/storage-services/service/pnp/cph/3a30000/3a31000/3a31100/3a31112_150px.jpg',
#     'url': 'https://www.loc.gov/resource/cph.3a31112/'}],
#   'shelf_id': 'LOT 7178 [item] [P&P]',
#   'site': ['pictures', 'catalog'],
#   'subject': ['chinatown (new york, n.y.)', 'photographic prints'],
#   'timestamp': '2021-09-04T12:39:10.141Z',
#   'title': '[Chinese-American father and daughter making New Year calls, Chinatown, New York City]',
#   'unrestricted': True,
#   'url': 'https://www.loc.gov/item/2001704343/'}]

# %% [markdown]
# > DataFrame it, while having the option to export the results to a spreadsheet file.

# %%
df = pd.DataFrame(output['results'])
df.head()
#df.to_excel('test.xlsx')
# Out:
#    access_restricted                                                aka  \
# 0              False  [http://www.loc.gov/item/ihas.200197427/, http...
# 1              False  [http://www.loc.gov/item/lcwaN0011557/, https:...
# 2              False  [http://www.loc.gov/item/powmia/pwmaster_10532...
# 3              False  [http://www.loc.gov/pictures/collection/det/it...
# 4              False  [http://www.loc.gov/pictures/collection/det/it...
#
#   campaigns                                        description  digitized  \
# 0        []  [<a href="http://www.loc.gov/pictures/resource...       True
# 1        []     [Website.   electronic |   Electronic (Form).]       True
# 2        []                 [post-1975 Vietnam / IIRN I80-019]       True
# 3        []                   [1 negative : glass ; 5 x 7 in.]       True
# 4        []                   [1 negative : glass ; 7 x 5 in.]       True
#
#           extract_timestamp  \
# 0  2022-12-27T09:59:46.399Z
# 1  2022-12-24T15:10:47.285Z
# 2  2022-12-16T14:19:18.334Z
# 3  2021-09-01T22:35:45.605Z
# 4  2021-09-01T22:35:44.834Z
#
#                                                group  hassegments  \
# 0         [special/artbios, music-division-articles]        False
# 1                             [general-web-archives]        False
# 2                                           [powmia]        False
# 3  [det, catalog, detroit-publishing-company, mai...        False
# 4  [det, catalog, detroit-publishing-company, mai...        False
#
#                                                 id  \
# 0          http://www.loc.gov/item/ihas.200197427/
# 1            http://www.loc.gov/item/lcwaN0011557/
# 2  http://www.loc.gov/item/powmia/pwmaster_105323/
# 3              http://www.loc.gov/item/2016817917/
# 4              http://www.loc.gov/item/2016817769/
#
#                                            image_url  ...  locations lonlat  \
# 0  [https://memory.loc.gov/natlib/ihas/warehouse/...  ...        NaN    NaN
# 1  [https://tile.loc.gov/storage-services/service...  ...        NaN    NaN
# 2  [https://tile.loc.gov/storage-services/service...  ...        NaN    NaN
# 3  [https://tile.loc.gov/storage-services/service...  ...        NaN    NaN
# 4  [https://tile.loc.gov/storage-services/service...  ...        NaN    NaN
#
#   number_carrier_type number_lccn number_source_modified number_oclc segments  \
# 0                 NaN         NaN                    NaN         NaN      NaN
# 1                 NaN         NaN                    NaN         NaN      NaN
# 2                 NaN         NaN                    NaN         NaN      NaN
# 3                 NaN         NaN                    NaN         NaN      NaN
# 4                 NaN         NaN                    NaN         NaN      NaN
#
#   location_city location_country location_state
# 0           NaN              NaN            NaN
# 1           NaN              NaN            NaN
# 2           NaN              NaN            NaN
# 3           NaN              NaN            NaN
# 4           NaN              NaN            NaN
#
# [5 rows x 54 columns]

# %% [markdown]
# > Similarly, specific metadata fields can be exported to a spreadsheet file as well

# %%
import csv
with open('OUTPUT.csv', 'w') as f:
    for key in o.keys():
        f.write("%s,%s\n"%(key,o[key]))
