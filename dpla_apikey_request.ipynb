# %%
import requests

# %%
r = requests.post("https://api.dp.la/v2/api_key/xiy051@ucsd.edu")

# %%
r
# Out:
# <Response [409]>

# %%
pip install dpla
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from dpla.api import DPLA

# %%
DPLA.new_key("xiy051@ucsd.edu")
# Out:
# Hmmm...there seems to have been an error.
